# %%
import pandas as pd
import faostat
import openpyxl

# %% [markdown]
# # Modeling Task
# Analyze how food waste relates to each of the following three target nutrition indicators (with potential mediation by per-capita food supply):
#
# - Dietary Energy Adequacy – The average dietary energy supply as a percentage of the population’s required energy needs.
# - Prevalence of Undernourishment – The share of the population that is chronically undernourished (consuming less than the minimum dietary energy requirement).
# - Prevalence of Obesity – The share of the adult population that is obese (BMI ≥ 30).
# <br>Mediating Factor: Food Supply per Capita – The average food availability per person, measured in kilocalories per person per day.
#
# Countries for Analysis
# | Region/Type         | Country  | Rationale                                                  |
# |---------------------|----------|-------------------------------------------------------------|
# | EU (mandatory)      | Bulgaria | Transitioning food system, moderate waste issues            |
# | High-income EU      | France   | Adequate diets, active waste-reduction policies             |
# | High-income EU      | Germany  | High surplus, distinct obesity profile                      |
# | Sub-Saharan Africa  | Nigeria  | High undernourishment, post-harvest losses                  |
# | South Asia          | India    | Large undernourished population, growing obesity            |
# | Latin America       | Brazil   | Rising obesity, emerging economy                            |
# | North America       | USA      | Very high obesity & waste, low hunger                       |
# | MENA                | Egypt    | High obesity, import-reliant, food insecurity               |
# | Southeast Asia      | Vietnam  | Rapid dietary shift, changing waste patterns                |
# | Latin America       | Mexico   | Obesity crisis, notable waste                               |

# %% [markdown]
# # Data download
# Downloading the data from Faostat API
#
# Datasets: <br>
# - FBSH - Food Balances (-2013, old methodology and population)
# - FBS - Food Balances (2010-)
# - FS - Suite of Food Security Indicators - dependent variables are here

# %%
#High-income EU	France	Adequate diets, active waste-reduction policies - 68
#High-income EU	Germany	High surplus, distinct obesity profile - 79
#Sub-Saharan Africa	Nigeria	High undernourishment, post-harvest losses - 159
#South Asia	India	Large undernourished population, growing obesity
#Latin America	Brazil	Rising obesity, emerging economy
#North America	USA	Very high obesity & waste, low hunger
#MENA	Egypt	High obesity, import-reliant, food insecurity
#Southeast Asia	Vietnam	Rapid dietary shift, changing waste patterns - 2nd
#Latin America	Mexico	Obesity crisis, notable waste - 138

# %%
faostat.list_datasets()
# Out:
# [('code',
#   'label',
#   'date_update',
#   'note_update',
#   'release_current',
#   'state_current',
#   'year_current',
#   'release_next',
#   'state_next',
#   'year_next'),
#  ('QCL',
#   'Crops and livestock products',
#   '2025-06-11',
#   'minor revision',
#   '2024-12-20 / 2025-06-11',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QI',
#   'Production Indices',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QV',
#   'Value of Agricultural Production',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('FS',
#   'Suite of Food Security Indicators',
#   '2025-03-27',
#   'minor revision',
#   '2024-07-24 / 2025-03-27',
#   'final',
#   '2023',
#   '2025-07',
#   'final',
#   '2024'),
#  ('FBS',
#   'Food Balances (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('SCL',
#   'Supply Utilization Accounts (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('CB',
#   'Commodity Balances (non-food) (2010-)',
#   '2024-07-19',
#   '',
#   '2024-07-19',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('FBSH',
#   'Food Balances (-2013, old methodology and population)',
#   '2023-03-10',
#   'minor revision',
#   '2016-12-20 / 2023-03-10',
#   'final',
#   '2013',
#   '',
#   '',
#   ''),
#  ('CBH',
#   'Commodity Balances (non-food) (-2013, old methodology)',
#   '2021-12-03',
#   'minor revision',
#   '2016-12-20 / 2021-12-03',
#   'final',
#   '2013',
#   '',
#   'final',
#   ''),
#  ('TCL',
#   'Crops and livestock products',
#   '2024-12-19',
#   '',
#   '2024-12-19',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('TM',
#   'Detailed trade matrix',
#   '2024-12-19',
#   '',
#   '2024-12-19',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('TI',
#   'Trade Indices',
#   '2024-12-19',
#   '',
#   '2024-12-19',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('TCLI',
#   'Crops and livestock products indicators',
#   '2024-12-19',
#   '',
#   '2024-12-19',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('PP',
#   'Producer Prices',
#   '2025-01-24',
#   '',
#   '2025-01-24',
#   'final',
#   '2024',
#   '2025-12',
#   'final',
#   '2025'),
#  ('CP',
#   'Consumer Price Indices',
#   '2025-06-18',
#   '',
#   '2025-06-18',
#   'preliminary',
#   '2024',
#   '2025-07',
#   'preliminary',
#   '2025'),
#  ('PD',
#   'Deflators',
#   '2025-06-06',
#   '',
#   '2025-06-06',
#   'final',
#   '2024',
#   '2025-10',
#   'preliminary',
#   '2024'),
#  ('PE',
#   'Exchange rates',
#   '2025-05-12',
#   '',
#   '2025-05-12',
#   'final',
#   '2024',
#   '2025-10',
#   'final',
#   '2024'),
#  ('CAHD',
#   'Cost and Affordability of a Healthy Diet (CoAHD)',
#   '2024-12-20',
#   '',
#   '2024-12-20',
#   'final',
#   '2022',
#   '2025-07',
#   'final',
#   '2023'),
#  ('SUA',
#   'Availability (based on supply utilization accounts)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '2022',
#   '2025-09',
#   'final',
#   '2023'),
#  ('HCES',
#   'Apparent intake (based on household consumption and expenditure surveys)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '',
#   '2025-09',
#   'final',
#   ''),
#  ('FDIQ',
#   'Intake (based on individual quantitative dietary surveys)',
#   '2024-12-04',
#   '',
#   '2024-12-04',
#   'final',
#   '',
#   '2024-09',
#   'final',
#   ''),
#  ('MDDW',
#   'Diversity (MDD-W, based on individual qualitative dietary surveys)',
#   '2024-12-12',
#   'minor revision',
#   '2024-12-04 / 2024-12-12',
#   'final',
#   '',
#   '2025-09',
#   'final',
#   ''),
#  ('RL',
#   'Land Use',
#   '2025-06-20',
#   '',
#   '2025-06-20',
#   'final',
#   '2023',
#   '2026-06',
#   'final',
#   '2024'),
#  ('LC',
#   'Land Cover',
#   '2025-06-20',
#   '',
#   '2025-06-20',
#   'final',
#   '2023',
#   '2026-06',
#   'final',
#   '2024'),
#  ('RFN',
#   'Fertilizers by Nutrient',
#   '2025-03-11',
#   'minor revision',
#   '2024-07-17 / 2025-03-11',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RFB',
#   'Fertilizers by Product',
#   '2025-03-11',
#   'minor revision',
#   '2024-07-17 / 2025-03-11',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RFM',
#   'Detailed trade matrix (fertilizers)',
#   '2024-07-17',
#   '',
#   '2024-07-17',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('EMN',
#   'Livestock Manure',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('RP',
#   'Pesticides Use',
#   '2024-09-26',
#   'minor revision',
#   '2024-07-16 / 2024-09-26',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('RT',
#   'Pesticides Trade',
#   '2024-09-23',
#   'minor revision',
#   '2024-07-16 / 2024-09-23',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('ESB',
#   'Cropland Nutrient Balance',
#   '2024-11-27',
#   '',
#   '2024-11-27',
#   'final',
#   '2022',
#   '2025-11',
#   'final',
#   '2023'),
#  ('EK',
#   'Livestock Patterns',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('BE',
#   'Bioenergy',
#   '2024-08-28',
#   'minor revision',
#   '2024-06-17 / 2024-08-28',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('ET',
#   'Temperature change on land',
#   '2025-03-28',
#   '',
#   '2025-03-28',
#   'final',
#   '2024',
#   '2026-03',
#   'final',
#   '2025'),
#  ('OA',
#   'Annual population',
#   '2024-12-31',
#   '',
#   '2024-12-31',
#   'final',
#   '2023',
#   '',
#   'final',
#   '2025'),
#  ('OEA',
#   'Employment Indicators: Agriculture and agrifood systems',
#   '2024-11-14',
#   'minor revision',
#   '2024-10-24 / 2024-11-14',
#   'final',
#   '2023',
#   '2025-04',
#   'final',
#   '2024'),
#  ('OER',
#   'Employment Indicators: Rural',
#   '2025-01-11',
#   'minor revision',
#   '2024-10-24 / 2025-01-11',
#   'final',
#   '2023',
#   '2025-04',
#   'final',
#   '2024'),
#  ('IG',
#   'Government Expenditure',
#   '2025-02-07',
#   '',
#   '2025-02-07',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('IC',
#   'Credit to Agriculture',
#   '2025-04-23',
#   'minor revision',
#   '2024-12-24 / 2025-04-23',
#   'final',
#   '2023',
#   '2025-11',
#   'final',
#   '2024'),
#  ('EA',
#   'Development Flows to Agriculture',
#   '2024-11-15',
#   '',
#   '2024-11-15',
#   'final',
#   '2022',
#   '2025-06',
#   'final',
#   '2023'),
#  ('FDI',
#   'Foreign Direct Investment (FDI)',
#   '2025-02-05',
#   '',
#   '2025-02-05',
#   'final',
#   '2023',
#   '2025-11',
#   'final',
#   '2024'),
#  ('CISP',
#   'Country Investment Statistics Profile',
#   '2025-06-12',
#   '',
#   '2025-06-12',
#   'preliminary',
#   '2023',
#   '2025-06',
#   'preliminary',
#   '2023'),
#  ('MK',
#   'Macro Indicators',
#   '2025-06-06',
#   '',
#   '2025-06-06',
#   'final',
#   '2024',
#   '2025-10',
#   'preliminary',
#   '2024'),
#  ('CS',
#   'Capital Stock',
#   '2025-05-16',
#   '',
#   '2025-05-16',
#   'final',
#   '2023',
#   '2025-11',
#   'final',
#   '2024'),
#  ('GFDI',
#   'Value shares by industry and primary factors',
#   '2024-11-19',
#   '',
#   '2024-11-19',
#   'final',
#   '2021',
#   '',
#   'final',
#   ''),
#  ('GT',
#   'Emissions totals',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('EM',
#   'Emissions indicators',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('EI',
#   'Emissions intensities',
#   '2025-02-12',
#   'minor revision',
#   '2024-11-14 / 2025-02-12',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GCE',
#   'Emissions from Crops',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GLE',
#   'Emissions from Livestock',
#   '2025-02-12',
#   'minor revision',
#   '2024-11-14 / 2025-02-12',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GN',
#   'Emissions from Energy use in agriculture',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GF',
#   'Emissions from Forests',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2023',
#   '2025-10',
#   'final',
#   '2024'),
#  ('GI',
#   'Emissions from Fires',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GV',
#   'Emissions from Drained organic soils',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('GPP',
#   'Emissions from pre and post agricultural production',
#   '2024-11-14',
#   '',
#   '2024-11-14',
#   'final',
#   '2022',
#   '2025-10',
#   'final',
#   '2023'),
#  ('FO',
#   'Forestry Production and Trade',
#   '2025-03-12',
#   'minor revision',
#   '2024-12-10 / 2025-03-12',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('FOP',
#   'Pulp and paper capacities, survey',
#   '2025-03-26',
#   '',
#   '2025-03-26',
#   'final',
#   '2025',
#   '2025-09',
#   'final',
#   '2026'),
#  ('SDGB',
#   'SDG Indicators',
#   '2025-05-15',
#   '',
#   '2025-05-15',
#   'final',
#   '2024',
#   '',
#   'final',
#   '2024'),
#  ('WCAD',
#   'Structural data from agricultural censuses',
#   '2025-05-12',
#   'minor revision',
#   '2025-04-11 / 2025-05-12',
#   'final',
#   '2020',
#   '2026-02',
#   'final',
#   '2020'),
#  ('FT',
#   'Forestry Trade Flows',
#   '2022-05-27',
#   'minor revision',
#   '2019-06-19 / 2022-05-27',
#   'final',
#   '2017',
#   '',
#   '',
#   ''),
#  ('HS',
#   'Indicators from Household Surveys (gender, area, socioeconomics)',
#   '2014-07-31',
#   '',
#   '2014-07-31',
#   'final',
#   '2014',
#   '',
#   '',
#   ''),
#  ('AF',
#   'ASTI-Researchers',
#   '2019-11-11',
#   '',
#   '2019-11-11',
#   'final',
#   '2016',
#   '',
#   'preliminary',
#   '2017'),
#  ('AE',
#   'ASTI-Expenditures',
#   '2019-11-11',
#   '',
#   '2019-11-11',
#   'final',
#   '2016',
#   '',
#   'preliminary',
#   '2017'),
#  ('FA',
#   'Food Aid Shipments (WFP)',
#   '2016-12-22',
#   '',
#   '2016-12-22',
#   'preliminary',
#   '2016',
#   '',
#   '',
#   ''),
#  ('RM',
#   'Machinery',
#   '2021-12-03',
#   'minor revision',
#   '2011-12-22 / 2021-12-03',
#   'final',
#   '2009',
#   '',
#   '',
#   ''),
#  ('RY',
#   'Machinery Archive',
#   '2021-12-03',
#   'minor revision',
#   '2006-12-31 / 2021-12-03',
#   'final',
#   '2005',
#   '',
#   '',
#   ''),
#  ('RA',
#   'Fertilizers archive',
#   '2020-09-08',
#   'minor revision',
#   '2013-12-31 / 2020-09-08',
#   'final',
#   '2002',
#   '',
#   '',
#   ''),
#  ('PA',
#   'Producer Prices (old series)',
#   '1991-12-31',
#   '',
#   '1991-12-31',
#   'final',
#   '1990',
#   '',
#   '',
#   '')]

# %%
faostat.list_pars('FBS'), faostat.list_pars('FBSH'), faostat.list_pars('FS')
# Out:
# ([('parameter code', 'coding_systems', 'subdimensions {code: meaning}'),
#   ('area',
#    ['M49', 'FAO', 'ISO2', 'ISO3'],
#    {'countries': 'Countries',
#     'regions': 'Regions',
#     'specialgroups': 'Special Groups'}),
#   ('element', [], {'elements': 'Elements'}),
#   ('item', ['FBS', 'FAO'], {'items': 'Items', 'itemsagg': 'Items Aggregated'}),
#   ('year', [], {'years': 'Years'})],
#  [('parameter code', 'coding_systems', 'subdimensions {code: meaning}'),
#   ('area',
#    ['M49', 'FAO', 'ISO2', 'ISO3'],
#    {'countries': 'Countries',
#     'regions': 'Regions',
#     'specialgroups': 'Special Groups'}),
#   ('element', [], {'elements': 'Elements'}),
#   ('item', ['FBS', 'FAO'], {'items': 'Items', 'itemsagg': 'Items Aggregated'}),
#   ('year', [], {'years': 'Years'})],
#  [('parameter code', 'coding_systems', 'subdimensions {code: meaning}'),
#   ('area',
#    ['M49', 'FAO', 'ISO2', 'ISO3'],
#    {'countries': 'Countries',
#     'regions': 'Regions',
#     'specialgroups': 'Special Groups'}),
#   ('element', [], {'elements': 'Elements'}),
#   ('item', [], {'items': 'Items'}),
#   ('year3', [], {'years3': 'Years'})])

# %%
#Obtain the code for required features
faostat.get_par('FS', 'element'), faostat.get_par('FS', 'items'), faostat.get_par('FS', 'area'), faostat.get_par('FS', 'year3')
# Out:
# ({'Value': '6120', 'Confidence interval': '6210'},
#  {'Featured Indicators > (List)': '21054>',
#   '-- Prevalence of undernourishment (percent)': '21004',
#   '-- Number of people undernourished (million)': '21001',
#   '-- Prevalence of severe food insecurity in the total population (percent)': '21040',
#   '-- Prevalence of moderate or severe food insecurity in the total population (percent)': '21009',
#   '-- Number of severely food insecure people (million)': '21007',
#   '-- Number of moderately or severely food insecure people (million)': '21008',
#   '-- Percentage of children under 5 years affected by wasting (percent)': '21026',
#   '-- Number of children under 5 years affected by wasting (million)': '210260',
#   '-- Percentage of children under 5 years of age who are stunted (modelled estimates) (percent)': '21025',
#   '-- Number of children under 5 years of age who are stunted (modeled estimates) (million)': '210250',
#   '-- Percentage of children under 5 years of age who are overweight (modelled estimates) (percent)': '21041',
#   '-- Number of children under 5 years of age who are overweight (modeled estimates) (million)': '210410',
#   '-- Prevalence of obesity in the adult population (18 years and older) (percent)': '21042',
#   '-- Number of obese adults (18 years and older) (million)': '210420',
#   '-- Prevalence of anemia among women of reproductive age (15-49 years) (percent)': '21043',
#   '-- Number of women of reproductive age (15-49 years) affected by anemia (million)': '210430',
#   '-- Prevalence of exclusive breastfeeding among infants 0-5 months of age (percent)': '21044',
#   '-- Prevalence of low birthweight (percent)': '21049',
#   '-- Number of newborns with low birthweight (million)': '210490',
#   'Availability > (List)': '21050>',
#   '-- Average dietary energy supply adequacy (percent) (3-year average)': '21010',
#   '-- Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)': '220001',
#   '-- Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)': '22000',
#   '-- Share of dietary energy supply derived from cereals, roots and tubers (percent) (3-year average)': '21012',
#   '-- Average protein supply (g/cap/day) (3-year average)': '21013',
#   '-- Average supply of protein of animal origin (g/cap/day) (3-year average)': '21014',
#   'Access > (List)': '21051>',
#   '-- Rail lines density (total route in km per 100 square km of land area)': '21016',
#   '-- Gross domestic product per capita, PPP, (constant 2017 international $)': '22013',
#   'Stability > (List)': '21053>',
#   '-- Cereal import dependency ratio (percent) (3-year average)': '21035',
#   '-- Percent of arable land equipped for irrigation (percent) (3-year average)': '21034',
#   '-- Value of food imports in total merchandise exports (percent) (3-year average)': '21033',
#   '-- Political stability and absence of violence/terrorism (index)': '21032',
#   '-- Per capita food supply variability (kcal/cap/day)': '21031',
#   'Utilization > (List)': '21052>',
#   '-- Percentage of population using safely managed drinking water services (percent)': '21045',
#   '-- Percentage of population using at least basic drinking water services (percent)': '21047',
#   '-- Percentage of population using safely managed sanitation services (percent)': '21046',
#   '-- Percentage of population using at least basic sanitation services (percent)': '21048',
#   'Other > (List)': '21055>',
#   '-- Minimum dietary energy requirement  (kcal/cap/day)': '21056',
#   '-- Average dietary energy requirement (kcal/cap/day)': '21057',
#   '-- Coefficient of variation of habitual caloric consumption distribution (real number)': '21058',
#   '-- Incidence of caloric losses at retail distribution level (percent)': '21059',
#   '-- Average fat supply (g/cap/day) (3-year average)': '21061'},
#  {'Afghanistan': '2',
#   'Albania': '3',
#   'Algeria': '4',
#   'American Samoa': '5',
#   'Andorra': '6',
#   'Angola': '7',
#   'Antigua and Barbuda': '8',
#   'Argentina': '9',
#   'Armenia': '1',
#   'Australia': '10',
#   'Austria': '11',
#   'Azerbaijan': '52',
#   'Bahamas': '12',
#   'Bahrain': '13',
#   'Bangladesh': '16',
#   'Barbados': '14',
#   'Belarus': '57',
#   'Belgium': '255',
#   'Belize': '23',
#   'Benin': '53',
#   'Bermuda': '17',
#   'Bhutan': '18',
#   'Bolivia (Plurinational State of)': '19',
#   'Bosnia and Herzegovina': '80',
#   'Botswana': '20',
#   'Brazil': '21',
#   'Brunei Darussalam': '26',
#   'Bulgaria': '27',
#   'Burkina Faso': '233',
#   'Burundi': '29',
#   'Cabo Verde': '35',
#   'Cambodia': '115',
#   'Cameroon': '32',
#   'Canada': '33',
#   'Central African Republic': '37',
#   'Chad': '39',
#   'Chile': '40',
#   'China': '351',
#   'China, Hong Kong SAR': '96',
#   'China, Macao SAR': '128',
#   'China, mainland': '41',
#   'China, Taiwan Province of': '214',
#   'Colombia': '44',
#   'Comoros': '45',
#   'Congo': '46',
#   'Cook Islands': '47',
#   'Costa Rica': '48',
#   "Côte d'Ivoire": '107',
#   'Croatia': '98',
#   'Cuba': '49',
#   'Cyprus': '50',
#   'Czechia': '167',
#   "Democratic People's Republic of Korea": '116',
#   'Democratic Republic of the Congo': '250',
#   'Denmark': '54',
#   'Djibouti': '72',
#   'Dominica': '55',
#   'Dominican Republic': '56',
#   'Ecuador': '58',
#   'Egypt': '59',
#   'El Salvador': '60',
#   'Equatorial Guinea': '61',
#   'Eritrea': '178',
#   'Estonia': '63',
#   'Eswatini': '209',
#   'Ethiopia': '238',
#   'Fiji': '66',
#   'Finland': '67',
#   'France': '68',
#   'French Polynesia': '70',
#   'Gabon': '74',
#   'Gambia': '75',
#   'Georgia': '73',
#   'Germany': '79',
#   'Ghana': '81',
#   'Greece': '84',
#   'Greenland': '85',
#   'Grenada': '86',
#   'Guatemala': '89',
#   'Guinea': '90',
#   'Guinea-Bissau': '175',
#   'Guyana': '91',
#   'Haiti': '93',
#   'Honduras': '95',
#   'Hungary': '97',
#   'Iceland': '99',
#   'India': '100',
#   'Indonesia': '101',
#   'Iran (Islamic Republic of)': '102',
#   'Iraq': '103',
#   'Ireland': '104',
#   'Israel': '105',
#   'Italy': '106',
#   'Jamaica': '109',
#   'Japan': '110',
#   'Jordan': '112',
#   'Kazakhstan': '108',
#   'Kenya': '114',
#   'Kiribati': '83',
#   'Kuwait': '118',
#   'Kyrgyzstan': '113',
#   "Lao People's Democratic Republic": '120',
#   'Latvia': '119',
#   'Lebanon': '121',
#   'Lesotho': '122',
#   'Liberia': '123',
#   'Libya': '124',
#   'Lithuania': '126',
#   'Luxembourg': '256',
#   'Madagascar': '129',
#   'Malawi': '130',
#   'Malaysia': '131',
#   'Maldives': '132',
#   'Mali': '133',
#   'Malta': '134',
#   'Marshall Islands': '127',
#   'Mauritania': '136',
#   'Mauritius': '137',
#   'Mexico': '138',
#   'Micronesia (Federated States of)': '145',
#   'Mongolia': '141',
#   'Montenegro': '273',
#   'Morocco': '143',
#   'Mozambique': '144',
#   'Myanmar': '28',
#   'Namibia': '147',
#   'Nauru': '148',
#   'Nepal': '149',
#   'Netherlands (Kingdom of the)': '150',
#   'New Caledonia': '153',
#   'New Zealand': '156',
#   'Nicaragua': '157',
#   'Niger': '158',
#   'Nigeria': '159',
#   'Niue': '160',
#   'North Macedonia': '154',
#   'Norway': '162',
#   'Oman': '221',
#   'Pakistan': '165',
#   'Palau': '180',
#   'Palestine': '299',
#   'Panama': '166',
#   'Papua New Guinea': '168',
#   'Paraguay': '169',
#   'Peru': '170',
#   'Philippines': '171',
#   'Poland': '173',
#   'Portugal': '174',
#   'Puerto Rico': '177',
#   'Qatar': '179',
#   'Republic of Korea': '117',
#   'Republic of Moldova': '146',
#   'Romania': '183',
#   'Russian Federation': '185',
#   'Rwanda': '184',
#   'Saint Kitts and Nevis': '188',
#   'Saint Lucia': '189',
#   'Saint Vincent and the Grenadines': '191',
#   'Samoa': '244',
#   'Sao Tome and Principe': '193',
#   'Saudi Arabia': '194',
#   'Senegal': '195',
#   'Serbia': '272',
#   'Seychelles': '196',
#   'Sierra Leone': '197',
#   'Singapore': '200',
#   'Slovakia': '199',
#   'Slovenia': '198',
#   'Solomon Islands': '25',
#   'Somalia': '201',
#   'South Africa': '202',
#   'South Sudan': '277',
#   'Spain': '203',
#   'Sri Lanka': '38',
#   'Sudan': '276',
#   'Suriname': '207',
#   'Sweden': '210',
#   'Switzerland': '211',
#   'Syrian Arab Republic': '212',
#   'Tajikistan': '208',
#   'Thailand': '216',
#   'Timor-Leste': '176',
#   'Togo': '217',
#   'Tokelau': '218',
#   'Tonga': '219',
#   'Trinidad and Tobago': '220',
#   'Tunisia': '222',
#   'Türkiye': '223',
#   'Turkmenistan': '213',
#   'Tuvalu': '227',
#   'Uganda': '226',
#   'Ukraine': '230',
#   'United Arab Emirates': '225',
#   'United Kingdom of Great Britain and Northern Ireland': '229',
#   'United Republic of Tanzania': '215',
#   'United States of America': '231',
#   'Uruguay': '234',
#   'Uzbekistan': '235',
#   'Vanuatu': '155',
#   'Venezuela (Bolivarian Republic of)': '236',
#   'Viet Nam': '237',
#   'Yemen': '249',
#   'Zambia': '251',
#   'Zimbabwe': '181',
#   'World + (Total)': '5000',
#   'World > (List)': '5000>',
#   'Africa + (Total)': '5100',
#   'Africa > (List)': '5100>',
#   '-- Eastern Africa + (Total)': '5101',
#   '-- Eastern Africa > (List)': '5101>',
#   '-- Middle Africa + (Total)': '5102',
#   '-- Middle Africa > (List)': '5102>',
#   '-- Northern Africa + (Total)': '5103',
#   '-- Northern Africa > (List)': '5103>',
#   '-- Northern Africa (excluding Sudan) + (Total)': '429',
#   '-- Northern Africa (excluding Sudan) > (List)': '429>',
#   '-- Southern Africa + (Total)': '5104',
#   '-- Southern Africa > (List)': '5104>',
#   '-- Western Africa + (Total)': '5105',
#   '-- Western Africa > (List)': '5105>',
#   '-- Sub-Saharan Africa + (Total)': '420',
#   '-- Sub-Saharan Africa > (List)': '420>',
#   '-- Sub-Saharan Africa (including Sudan) + (Total)': '5810',
#   '-- Sub-Saharan Africa (including Sudan) > (List)': '5810>',
#   'Northern America and Europe + (Total)': '5208',
#   'Northern America and Europe > (List)': '5208>',
#   '-- Northern America + (Total)': '5203',
#   '-- Northern America > (List)': '5203>',
#   '-- Europe + (Total)': '5400',
#   '-- Europe > (List)': '5400>',
#   '-- Eastern Europe + (Total)': '5401',
#   '-- Eastern Europe > (List)': '5401>',
#   '-- Northern Europe + (Total)': '5402',
#   '-- Northern Europe > (List)': '5402>',
#   '-- Southern Europe + (Total)': '5403',
#   '-- Southern Europe > (List)': '5403>',
#   '-- Western Europe + (Total)': '5404',
#   '-- Western Europe > (List)': '5404>',
#   'Latin America and the Caribbean + (Total)': '5205',
#   'Latin America and the Caribbean > (List)': '5205>',
#   '-- Central America + (Total)': '5204',
#   '-- Central America > (List)': '5204>',
#   '-- Caribbean + (Total)': '5206',
#   '-- Caribbean > (List)': '5206>',
#   '-- South America + (Total)': '5207',
#   '-- South America > (List)': '5207>',
#   'Asia + (Total)': '5300',
#   'Asia > (List)': '5300>',
#   '-- Central Asia + (Total)': '5301',
#   '-- Central Asia > (List)': '5301>',
#   '-- Eastern Asia + (Total)': '5302',
#   '-- Eastern Asia > (List)': '5302>',
#   '-- Southern Asia + (Total)': '5303',
#   '-- Southern Asia > (List)': '5303>',
#   '-- Southern Asia (excluding India) + (Total)': '5855',
#   '-- Southern Asia (excluding India) > (List)': '5855>',
#   '-- South-eastern Asia + (Total)': '5304',
#   '-- South-eastern Asia > (List)': '5304>',
#   '-- Western Asia + (Total)': '5305',
#   '-- Western Asia > (List)': '5305>',
#   '-- Central Asia and Southern Asia + (Total)': '5306',
#   '-- Central Asia and Southern Asia > (List)': '5306>',
#   '-- Eastern Asia and South-eastern Asia + (Total)': '5307',
#   '-- Eastern Asia and South-eastern Asia > (List)': '5307>',
#   '-- Western Asia and Northern Africa + (Total)': '5308',
#   '-- Western Asia and Northern Africa > (List)': '5308>',
#   'Oceania + (Total)': '5500',
#   'Oceania > (List)': '5500>',
#   '-- Australia and New Zealand + (Total)': '5501',
#   '-- Australia and New Zealand > (List)': '5501>',
#   '-- Melanesia + (Total)': '5502',
#   '-- Melanesia > (List)': '5502>',
#   '-- Micronesia + (Total)': '5503',
#   '-- Micronesia > (List)': '5503>',
#   '-- Polynesia + (Total)': '5504',
#   '-- Polynesia > (List)': '5504>',
#   '-- Oceania excluding Australia and New Zealand + (Total)': '5807',
#   '-- Oceania excluding Australia and New Zealand > (List)': '5807>',
#   'Least Developed Countries (LDCs) + (Total)': '5801',
#   'Least Developed Countries (LDCs) > (List)': '5801>',
#   'Land Locked Developing Countries (LLDCs) + (Total)': '5802',
#   'Land Locked Developing Countries (LLDCs) > (List)': '5802>',
#   'Small Island Developing States (SIDS) + (Total)': '5803',
#   'Small Island Developing States (SIDS) > (List)': '5803>',
#   'Low Income Food Deficit Countries (LIFDCs) + (Total)': '5815',
#   'Low Income Food Deficit Countries (LIFDCs) > (List)': '5815>',
#   'Low-income economies + (Total)': '5858',
#   'Low-income economies > (List)': '5858>',
#   'Lower-middle-income economies + (Total)': '5859',
#   'Lower-middle-income economies > (List)': '5859>',
#   'High-income economies + (Total)': '9010',
#   'High-income economies > (List)': '9010>',
#   'Upper-middle-income economies + (Total)': '9011',
#   'Upper-middle-income economies > (List)': '9011>'},
#  {'2023 / 2022-2024': '20233',
#   '2022 / 2021-2023': '20223',
#   '2021 / 2020-2022': '20213',
#   '2020 / 2019-2021': '20203',
#   '2019 / 2018-2020': '20193',
#   '2018 / 2017-2019': '20183',
#   '2017 / 2016-2018': '20173',
#   '2016 / 2015-2017': '20163',
#   '2015 / 2014-2016': '20153',
#   '2014 / 2013-2015': '20143',
#   '2013 / 2012-2014': '20133',
#   '2012 / 2011-2013': '20123',
#   '2011 / 2010-2012': '20113',
#   '2010 / 2009-2011': '20103',
#   '2009 / 2008-2010': '20093',
#   '2008 / 2007-2009': '20083',
#   '2007 / 2006-2008': '20073',
#   '2006 / 2005-2007': '20063',
#   '2005 / 2004-2006': '20053',
#   '2004 / 2003-2005': '20043',
#   '2003 / 2002-2004': '20033',
#   '2002 / 2001-2003': '20023',
#   '2001 / 2000-2002': '20013',
#   '2000 / 1999-2001': '20003'})

# %%
faostat.get_par('FBSH', 'element'), faostat.get_par('FBSH', 'itemsagg'), faostat.get_par('FBSH', 'items'), faostat.get_par('FBSH', 'area')
# Out:
# ({'Total Population - Both sexes': '511',
#   'Production Quantity': '2510',
#   'Import Quantity': '2610',
#   'Stock Variation': '2071',
#   'Export Quantity': '2910',
#   'Domestic supply quantity': '2300',
#   'Feed': '2520',
#   'Seed': '2525',
#   'Losses': '2120',
#   'Processed': '2130',
#   'Other uses (non-food)': '2151',
#   'Tourist consumption': '5171',
#   'Residuals': '5170',
#   'Food': '2141',
#   'Food supply quantity (kg/capita/yr)': '645',
#   'Food supply (kcal/capita/day)': '664',
#   'Protein supply quantity (g/capita/day)': '674',
#   'Fat supply quantity (g/capita/day)': '684'},
#  {'Grand Total + (Total)': '2901',
#   'Grand Total > (List)': '2901>',
#   'Vegetal Products + (Total)': '2903',
#   'Vegetal Products > (List)': '2903>',
#   'Animal Products + (Total)': '2941',
#   'Animal Products > (List)': '2941>',
#   'Cereals - Excluding Beer + (Total)': '2905',
#   'Cereals - Excluding Beer > (List)': '2905>',
#   'Starchy Roots + (Total)': '2907',
#   'Starchy Roots > (List)': '2907>',
#   'Sugar Crops + (Total)': '2908',
#   'Sugar Crops > (List)': '2908>',
#   'Sugar & Sweeteners + (Total)': '2909',
#   'Sugar & Sweeteners > (List)': '2909>',
#   'Pulses + (Total)': '2911',
#   'Pulses > (List)': '2911>',
#   'Treenuts + (Total)': '2912',
#   'Treenuts > (List)': '2912>',
#   'Oilcrops + (Total)': '2913',
#   'Oilcrops > (List)': '2913>',
#   'Vegetable Oils + (Total)': '2914',
#   'Vegetable Oils > (List)': '2914>',
#   'Vegetables + (Total)': '2918',
#   'Vegetables > (List)': '2918>',
#   'Fruits - Excluding Wine + (Total)': '2919',
#   'Fruits - Excluding Wine > (List)': '2919>',
#   'Stimulants + (Total)': '2922',
#   'Stimulants > (List)': '2922>',
#   'Spices + (Total)': '2923',
#   'Spices > (List)': '2923>',
#   'Alcoholic Beverages + (Total)': '2924',
#   'Alcoholic Beverages > (List)': '2924>',
#   'Meat + (Total)': '2943',
#   'Meat > (List)': '2943>',
#   'Offals + (Total)': '2945',
#   'Offals > (List)': '2945>',
#   'Animal fats + (Total)': '2946',
#   'Animal fats > (List)': '2946>',
#   'Eggs + (Total)': '2949',
#   'Eggs > (List)': '2949>',
#   'Milk - Excluding Butter + (Total)': '2948',
#   'Milk - Excluding Butter > (List)': '2948>',
#   'Fish, Seafood + (Total)': '2960',
#   'Fish, Seafood > (List)': '2960>',
#   'Aquatic Products, Other + (Total)': '2961',
#   'Aquatic Products, Other > (List)': '2961>',
#   'Miscellaneous + (Total)': '2928',
#   'Miscellaneous > (List)': '2928>'},
#  {'Population': '2501',
#   'Wheat and products': '2511',
#   'Rice (Milled Equivalent)': '2805',
#   'Barley and products': '2513',
#   'Maize and products': '2514',
#   'Rye and products': '2515',
#   'Oats': '2516',
#   'Millet and products': '2517',
#   'Sorghum and products': '2518',
#   'Cereals, Other': '2520',
#   'Cassava and products': '2532',
#   'Potatoes and products': '2531',
#   'Sweet potatoes': '2533',
#   'Yams': '2535',
#   'Roots, Other': '2534',
#   'Sugar cane': '2536',
#   'Sugar beet': '2537',
#   'Sugar non-centrifugal': '2541',
#   'Sugar (Raw Equivalent)': '2542',
#   'Sweeteners, Other': '2543',
#   'Honey': '2745',
#   'Beans': '2546',
#   'Peas': '2547',
#   'Pulses, Other and products': '2549',
#   'Nuts and products': '2551',
#   'Soyabeans': '2555',
#   'Groundnuts (Shelled Eq)': '2556',
#   'Sunflower seed': '2557',
#   'Rape and Mustardseed': '2558',
#   'Cottonseed': '2559',
#   'Coconuts - Incl Copra': '2560',
#   'Sesame seed': '2561',
#   'Palm kernels': '2562',
#   'Olives (including preserved)': '2563',
#   'Oilcrops, Other': '2570',
#   'Soyabean Oil': '2571',
#   'Groundnut Oil': '2572',
#   'Sunflowerseed Oil': '2573',
#   'Rape and Mustard Oil': '2574',
#   'Cottonseed Oil': '2575',
#   'Palmkernel Oil': '2576',
#   'Palm Oil': '2577',
#   'Coconut Oil': '2578',
#   'Sesameseed Oil': '2579',
#   'Olive Oil': '2580',
#   'Ricebran Oil': '2581',
#   'Maize Germ Oil': '2582',
#   'Oilcrops Oil, Other': '2586',
#   'Tomatoes and products': '2601',
#   'Onions': '2602',
#   'Vegetables, other': '2605',
#   'Oranges, Mandarines': '2611',
#   'Lemons, Limes and products': '2612',
#   'Grapefruit and products': '2613',
#   'Citrus, Other': '2614',
#   'Bananas': '2615',
#   'Plantains': '2616',
#   'Apples and products': '2617',
#   'Pineapples and products': '2618',
#   'Dates': '2619',
#   'Grapes and products (excl wine)': '2620',
#   'Fruits, other': '2625',
#   'Coffee and products': '2630',
#   'Cocoa Beans and products': '2633',
#   'Tea (including mate)': '2635',
#   'Pepper': '2640',
#   'Pimento': '2641',
#   'Cloves': '2642',
#   'Spices, Other': '2645',
#   'Wine': '2655',
#   'Beer': '2656',
#   'Beverages, Fermented': '2657',
#   'Beverages, Alcoholic': '2658',
#   'Alcohol, Non-Food': '2659',
#   'Bovine Meat': '2731',
#   'Mutton & Goat Meat': '2732',
#   'Pigmeat': '2733',
#   'Poultry Meat': '2734',
#   'Meat, Other': '2735',
#   'Offals, Edible': '2736',
#   'Butter, Ghee': '2740',
#   'Cream': '2743',
#   'Fats, Animals, Raw': '2737',
#   'Fish, Body Oil': '2781',
#   'Fish, Liver Oil': '2782',
#   'Eggs': '2744',
#   'Milk - Excluding Butter': '2848',
#   'Freshwater Fish': '2761',
#   'Demersal Fish': '2762',
#   'Pelagic Fish': '2763',
#   'Marine Fish, Other': '2764',
#   'Crustaceans': '2765',
#   'Cephalopods': '2766',
#   'Molluscs, Other': '2767',
#   'Aquatic Animals, Others': '2769',
#   'Meat, Aquatic Mammals': '2768',
#   'Aquatic Plants': '2775',
#   'Infant food': '2680',
#   'Miscellaneous': '2899'},
#  {'Afghanistan': '2',
#   'Albania': '3',
#   'Algeria': '4',
#   'Angola': '7',
#   'Antigua and Barbuda': '8',
#   'Argentina': '9',
#   'Armenia': '1',
#   'Australia': '10',
#   'Austria': '11',
#   'Azerbaijan': '52',
#   'Bahamas': '12',
#   'Bangladesh': '16',
#   'Barbados': '14',
#   'Belarus': '57',
#   'Belgium': '255',
#   'Belgium-Luxembourg': '15',
#   'Belize': '23',
#   'Benin': '53',
#   'Bermuda': '17',
#   'Bolivia (Plurinational State of)': '19',
#   'Bosnia and Herzegovina': '80',
#   'Botswana': '20',
#   'Brazil': '21',
#   'Brunei Darussalam': '26',
#   'Bulgaria': '27',
#   'Burkina Faso': '233',
#   'Cabo Verde': '35',
#   'Cambodia': '115',
#   'Cameroon': '32',
#   'Canada': '33',
#   'Central African Republic': '37',
#   'Chad': '39',
#   'Chile': '40',
#   'China': '351',
#   'China, Hong Kong SAR': '96',
#   'China, Macao SAR': '128',
#   'China, mainland': '41',
#   'China, Taiwan Province of': '214',
#   'Colombia': '44',
#   'Congo': '46',
#   'Costa Rica': '48',
#   "Côte d'Ivoire": '107',
#   'Croatia': '98',
#   'Cuba': '49',
#   'Cyprus': '50',
#   'Czechia': '167',
#   'Czechoslovakia': '51',
#   "Democratic People's Republic of Korea": '116',
#   'Denmark': '54',
#   'Djibouti': '72',
#   'Dominica': '55',
#   'Dominican Republic': '56',
#   'Ecuador': '58',
#   'Egypt': '59',
#   'El Salvador': '60',
#   'Estonia': '63',
#   'Eswatini': '209',
#   'Ethiopia': '238',
#   'Ethiopia PDR': '62',
#   'Fiji': '66',
#   'Finland': '67',
#   'France': '68',
#   'French Polynesia': '70',
#   'Gabon': '74',
#   'Gambia': '75',
#   'Georgia': '73',
#   'Germany': '79',
#   'Ghana': '81',
#   'Greece': '84',
#   'Grenada': '86',
#   'Guatemala': '89',
#   'Guinea': '90',
#   'Guinea-Bissau': '175',
#   'Guyana': '91',
#   'Haiti': '93',
#   'Honduras': '95',
#   'Hungary': '97',
#   'Iceland': '99',
#   'India': '100',
#   'Indonesia': '101',
#   'Iran (Islamic Republic of)': '102',
#   'Iraq': '103',
#   'Ireland': '104',
#   'Israel': '105',
#   'Italy': '106',
#   'Jamaica': '109',
#   'Japan': '110',
#   'Jordan': '112',
#   'Kazakhstan': '108',
#   'Kenya': '114',
#   'Kiribati': '83',
#   'Kuwait': '118',
#   'Kyrgyzstan': '113',
#   "Lao People's Democratic Republic": '120',
#   'Latvia': '119',
#   'Lebanon': '121',
#   'Lesotho': '122',
#   'Liberia': '123',
#   'Lithuania': '126',
#   'Luxembourg': '256',
#   'Madagascar': '129',
#   'Malawi': '130',
#   'Malaysia': '131',
#   'Maldives': '132',
#   'Mali': '133',
#   'Malta': '134',
#   'Mauritania': '136',
#   'Mauritius': '137',
#   'Mexico': '138',
#   'Mongolia': '141',
#   'Montenegro': '273',
#   'Morocco': '143',
#   'Mozambique': '144',
#   'Myanmar': '28',
#   'Namibia': '147',
#   'Nepal': '149',
#   'Netherlands (Kingdom of the)': '150',
#   'Netherlands Antilles (former)': '151',
#   'New Caledonia': '153',
#   'New Zealand': '156',
#   'Nicaragua': '157',
#   'Niger': '158',
#   'Nigeria': '159',
#   'North Macedonia': '154',
#   'Norway': '162',
#   'Oman': '221',
#   'Pakistan': '165',
#   'Panama': '166',
#   'Paraguay': '169',
#   'Peru': '170',
#   'Philippines': '171',
#   'Poland': '173',
#   'Portugal': '174',
#   'Republic of Korea': '117',
#   'Republic of Moldova': '146',
#   'Romania': '183',
#   'Russian Federation': '185',
#   'Rwanda': '184',
#   'Saint Kitts and Nevis': '188',
#   'Saint Lucia': '189',
#   'Saint Vincent and the Grenadines': '191',
#   'Samoa': '244',
#   'Sao Tome and Principe': '193',
#   'Saudi Arabia': '194',
#   'Senegal': '195',
#   'Serbia': '272',
#   'Serbia and Montenegro': '186',
#   'Sierra Leone': '197',
#   'Slovakia': '199',
#   'Slovenia': '198',
#   'Solomon Islands': '25',
#   'South Africa': '202',
#   'Spain': '203',
#   'Sri Lanka': '38',
#   'Sudan': '276',
#   'Sudan (former)': '206',
#   'Suriname': '207',
#   'Sweden': '210',
#   'Switzerland': '211',
#   'Tajikistan': '208',
#   'Thailand': '216',
#   'Timor-Leste': '176',
#   'Togo': '217',
#   'Trinidad and Tobago': '220',
#   'Tunisia': '222',
#   'Türkiye': '223',
#   'Turkmenistan': '213',
#   'Uganda': '226',
#   'Ukraine': '230',
#   'United Arab Emirates': '225',
#   'United Kingdom of Great Britain and Northern Ireland': '229',
#   'United Republic of Tanzania': '215',
#   'United States of America': '231',
#   'Uruguay': '234',
#   'USSR': '228',
#   'Uzbekistan': '235',
#   'Vanuatu': '155',
#   'Venezuela (Bolivarian Republic of)': '236',
#   'Viet Nam': '237',
#   'Yemen': '249',
#   'Yugoslav SFR': '248',
#   'Zambia': '251',
#   'Zimbabwe': '181',
#   'World + (Total)': '5000',
#   'World > (List)': '5000>',
#   'Africa + (Total)': '5100',
#   'Africa > (List)': '5100>',
#   '-- Eastern Africa + (Total)': '5101',
#   '-- Eastern Africa > (List)': '5101>',
#   '-- Middle Africa + (Total)': '5102',
#   '-- Middle Africa > (List)': '5102>',
#   '-- Northern Africa + (Total)': '5103',
#   '-- Northern Africa > (List)': '5103>',
#   '-- Southern Africa + (Total)': '5104',
#   '-- Southern Africa > (List)': '5104>',
#   '-- Western Africa + (Total)': '5105',
#   '-- Western Africa > (List)': '5105>',
#   'Americas + (Total)': '5200',
#   'Americas > (List)': '5200>',
#   '-- Northern America + (Total)': '5203',
#   '-- Northern America > (List)': '5203>',
#   '-- Central America + (Total)': '5204',
#   '-- Central America > (List)': '5204>',
#   '-- Caribbean + (Total)': '5206',
#   '-- Caribbean > (List)': '5206>',
#   '-- South America + (Total)': '5207',
#   '-- South America > (List)': '5207>',
#   'Asia + (Total)': '5300',
#   'Asia > (List)': '5300>',
#   '-- Central Asia + (Total)': '5301',
#   '-- Central Asia > (List)': '5301>',
#   '-- Eastern Asia + (Total)': '5302',
#   '-- Eastern Asia > (List)': '5302>',
#   '-- Southern Asia + (Total)': '5303',
#   '-- Southern Asia > (List)': '5303>',
#   '-- South-eastern Asia + (Total)': '5304',
#   '-- South-eastern Asia > (List)': '5304>',
#   '-- Western Asia + (Total)': '5305',
#   '-- Western Asia > (List)': '5305>',
#   'Europe + (Total)': '5400',
#   'Europe > (List)': '5400>',
#   '-- Eastern Europe + (Total)': '5401',
#   '-- Eastern Europe > (List)': '5401>',
#   '-- Northern Europe + (Total)': '5402',
#   '-- Northern Europe > (List)': '5402>',
#   '-- Southern Europe + (Total)': '5403',
#   '-- Southern Europe > (List)': '5403>',
#   '-- Western Europe + (Total)': '5404',
#   '-- Western Europe > (List)': '5404>',
#   'Oceania + (Total)': '5500',
#   'Oceania > (List)': '5500>',
#   '-- Australia and New Zealand + (Total)': '5501',
#   '-- Australia and New Zealand > (List)': '5501>',
#   '-- Melanesia + (Total)': '5502',
#   '-- Melanesia > (List)': '5502>',
#   '-- Micronesia + (Total)': '5503',
#   '-- Micronesia > (List)': '5503>',
#   '-- Polynesia + (Total)': '5504',
#   '-- Polynesia > (List)': '5504>',
#   'European Union (27) + (Total)': '5707',
#   'European Union (27) > (List)': '5707>',
#   'Least Developed Countries (LDCs) + (Total)': '5801',
#   'Least Developed Countries (LDCs) > (List)': '5801>',
#   'Land Locked Developing Countries (LLDCs) + (Total)': '5802',
#   'Land Locked Developing Countries (LLDCs) > (List)': '5802>',
#   'Small Island Developing States (SIDS) + (Total)': '5803',
#   'Small Island Developing States (SIDS) > (List)': '5803>',
#   'Low Income Food Deficit Countries (LIFDCs) + (Total)': '5815',
#   'Low Income Food Deficit Countries (LIFDCs) > (List)': '5815>',
#   'Net Food Importing Developing Countries (NFIDCs) + (Total)': '5817',
#   'Net Food Importing Developing Countries (NFIDCs) > (List)': '5817>'})

# %%
faostat.get_par('FBS', 'element'), faostat.get_par('FBS', 'itemsagg'), faostat.get_par('FBS', 'items'), faostat.get_par('FBS', 'area')
# Out:
# ({'Total Population - Both sexes': '511',
#   'Production Quantity': '2510',
#   'Import quantity': '2610',
#   'Stock Variation': '2071',
#   'Export quantity': '2910',
#   'Domestic supply quantity': '2300',
#   'Feed': '2520',
#   'Seed': '2525',
#   'Losses': '2120',
#   'Processed': '2130',
#   'Other uses (non-food)': '2151',
#   'Tourist consumption': '5171',
#   'Residuals': '5170',
#   'Food': '2141',
#   'Food supply quantity (kg/capita/yr)': '645',
#   'Food supply (kcal/capita/day)': '664',
#   'Food supply (kcal)': '661',
#   'Protein supply quantity (g/capita/day)': '674',
#   'Protein supply quantity (t)': '671',
#   'Fat supply quantity (g/capita/day)': '684',
#   'Fat supply quantity (t)': '681'},
#  {'Grand Total + (Total)': '2901',
#   'Grand Total > (List)': '2901>',
#   'Vegetal Products + (Total)': '2903',
#   'Vegetal Products > (List)': '2903>',
#   'Animal Products + (Total)': '2941',
#   'Animal Products > (List)': '2941>',
#   'Cereals - Excluding Beer + (Total)': '2905',
#   'Cereals - Excluding Beer > (List)': '2905>',
#   'Starchy Roots + (Total)': '2907',
#   'Starchy Roots > (List)': '2907>',
#   'Sugar Crops + (Total)': '2908',
#   'Sugar Crops > (List)': '2908>',
#   'Sugar & Sweeteners + (Total)': '2909',
#   'Sugar & Sweeteners > (List)': '2909>',
#   'Pulses + (Total)': '2911',
#   'Pulses > (List)': '2911>',
#   'Treenuts + (Total)': '2912',
#   'Treenuts > (List)': '2912>',
#   'Oilcrops + (Total)': '2913',
#   'Oilcrops > (List)': '2913>',
#   'Vegetable Oils + (Total)': '2914',
#   'Vegetable Oils > (List)': '2914>',
#   'Vegetables + (Total)': '2918',
#   'Vegetables > (List)': '2918>',
#   'Fruits - Excluding Wine + (Total)': '2919',
#   'Fruits - Excluding Wine > (List)': '2919>',
#   'Stimulants + (Total)': '2922',
#   'Stimulants > (List)': '2922>',
#   'Spices + (Total)': '2923',
#   'Spices > (List)': '2923>',
#   'Alcoholic Beverages + (Total)': '2924',
#   'Alcoholic Beverages > (List)': '2924>',
#   'Meat + (Total)': '2943',
#   'Meat > (List)': '2943>',
#   'Offals + (Total)': '2945',
#   'Offals > (List)': '2945>',
#   'Animal fats + (Total)': '2946',
#   'Animal fats > (List)': '2946>',
#   'Eggs + (Total)': '2949',
#   'Eggs > (List)': '2949>',
#   'Milk - Excluding Butter + (Total)': '2948',
#   'Milk - Excluding Butter > (List)': '2948>',
#   'Fish, Seafood + (Total)': '2960',
#   'Fish, Seafood > (List)': '2960>',
#   'Aquatic Products, Other + (Total)': '2961',
#   'Aquatic Products, Other > (List)': '2961>',
#   'Miscellaneous + (Total)': '2928',
#   'Miscellaneous > (List)': '2928>'},
#  {'Population': '2501',
#   'Wheat and products': '2511',
#   'Rice and products': '2807',
#   'Barley and products': '2513',
#   'Maize and products': '2514',
#   'Rye and products': '2515',
#   'Oats': '2516',
#   'Millet and products': '2517',
#   'Sorghum and products': '2518',
#   'Cereals, other': '2520',
#   'Cassava and products': '2532',
#   'Potatoes and products': '2531',
#   'Sweet potatoes': '2533',
#   'Yams': '2535',
#   'Roots, Other': '2534',
#   'Sugar cane': '2536',
#   'Sugar beet': '2537',
#   'Sugar non-centrifugal': '2541',
#   'Sugar (Raw Equivalent)': '2542',
#   'Sweeteners, Other': '2543',
#   'Honey': '2745',
#   'Beans': '2546',
#   'Peas': '2547',
#   'Pulses, Other and products': '2549',
#   'Nuts and products': '2551',
#   'Soyabeans': '2555',
#   'Groundnuts': '2552',
#   'Sunflower seed': '2557',
#   'Rape and Mustardseed': '2558',
#   'Cottonseed': '2559',
#   'Coconuts - Incl Copra': '2560',
#   'Sesame seed': '2561',
#   'Palm kernels': '2562',
#   'Olives (including preserved)': '2563',
#   'Oilcrops, Other': '2570',
#   'Soyabean Oil': '2571',
#   'Groundnut Oil': '2572',
#   'Sunflowerseed Oil': '2573',
#   'Rape and Mustard Oil': '2574',
#   'Cottonseed Oil': '2575',
#   'Palmkernel Oil': '2576',
#   'Palm Oil': '2577',
#   'Coconut Oil': '2578',
#   'Sesameseed Oil': '2579',
#   'Olive Oil': '2580',
#   'Ricebran Oil': '2581',
#   'Maize Germ Oil': '2582',
#   'Oilcrops Oil, Other': '2586',
#   'Tomatoes and products': '2601',
#   'Onions': '2602',
#   'Vegetables, other': '2605',
#   'Oranges, Mandarines': '2611',
#   'Lemons, Limes and products': '2612',
#   'Grapefruit and products': '2613',
#   'Citrus, Other': '2614',
#   'Bananas': '2615',
#   'Plantains': '2616',
#   'Apples and products': '2617',
#   'Pineapples and products': '2618',
#   'Dates': '2619',
#   'Grapes and products (excl wine)': '2620',
#   'Fruits, other': '2625',
#   'Coffee and products': '2630',
#   'Cocoa Beans and products': '2633',
#   'Tea (including mate)': '2635',
#   'Pepper': '2640',
#   'Pimento': '2641',
#   'Cloves': '2642',
#   'Spices, Other': '2645',
#   'Wine': '2655',
#   'Beer': '2656',
#   'Beverages, Fermented': '2657',
#   'Beverages, Alcoholic': '2658',
#   'Alcohol, Non-Food': '2659',
#   'Bovine Meat': '2731',
#   'Mutton & Goat Meat': '2732',
#   'Pigmeat': '2733',
#   'Poultry Meat': '2734',
#   'Meat, Other': '2735',
#   'Offals, Edible': '2736',
#   'Butter, Ghee': '2740',
#   'Cream': '2743',
#   'Fats, Animals, Raw': '2737',
#   'Fish, Body Oil': '2781',
#   'Fish, Liver Oil': '2782',
#   'Eggs': '2744',
#   'Milk - Excluding Butter': '2848',
#   'Freshwater Fish': '2761',
#   'Demersal Fish': '2762',
#   'Pelagic Fish': '2763',
#   'Marine Fish, Other': '2764',
#   'Crustaceans': '2765',
#   'Cephalopods': '2766',
#   'Molluscs, Other': '2767',
#   'Aquatic Animals, Others': '2769',
#   'Meat, Aquatic Mammals': '2768',
#   'Aquatic Plants': '2775',
#   'Infant food': '2680',
#   'Miscellaneous': '2899'},
#  {'Afghanistan': '2',
#   'Albania': '3',
#   'Algeria': '4',
#   'Angola': '7',
#   'Antigua and Barbuda': '8',
#   'Argentina': '9',
#   'Armenia': '1',
#   'Australia': '10',
#   'Austria': '11',
#   'Azerbaijan': '52',
#   'Bahamas': '12',
#   'Bahrain': '13',
#   'Bangladesh': '16',
#   'Barbados': '14',
#   'Belarus': '57',
#   'Belgium': '255',
#   'Belize': '23',
#   'Benin': '53',
#   'Bhutan': '18',
#   'Bolivia (Plurinational State of)': '19',
#   'Bosnia and Herzegovina': '80',
#   'Botswana': '20',
#   'Brazil': '21',
#   'Bulgaria': '27',
#   'Burkina Faso': '233',
#   'Burundi': '29',
#   'Cabo Verde': '35',
#   'Cambodia': '115',
#   'Cameroon': '32',
#   'Canada': '33',
#   'Central African Republic': '37',
#   'Chad': '39',
#   'Chile': '40',
#   'China': '351',
#   'China, Hong Kong SAR': '96',
#   'China, Macao SAR': '128',
#   'China, mainland': '41',
#   'China, Taiwan Province of': '214',
#   'Colombia': '44',
#   'Comoros': '45',
#   'Congo': '46',
#   'Costa Rica': '48',
#   "Côte d'Ivoire": '107',
#   'Croatia': '98',
#   'Cuba': '49',
#   'Cyprus': '50',
#   'Czechia': '167',
#   "Democratic People's Republic of Korea": '116',
#   'Democratic Republic of the Congo': '250',
#   'Denmark': '54',
#   'Djibouti': '72',
#   'Dominica': '55',
#   'Dominican Republic': '56',
#   'Ecuador': '58',
#   'Egypt': '59',
#   'El Salvador': '60',
#   'Estonia': '63',
#   'Eswatini': '209',
#   'Ethiopia': '238',
#   'Fiji': '66',
#   'Finland': '67',
#   'France': '68',
#   'French Polynesia': '70',
#   'Gabon': '74',
#   'Gambia': '75',
#   'Georgia': '73',
#   'Germany': '79',
#   'Ghana': '81',
#   'Greece': '84',
#   'Grenada': '86',
#   'Guatemala': '89',
#   'Guinea': '90',
#   'Guinea-Bissau': '175',
#   'Guyana': '91',
#   'Haiti': '93',
#   'Honduras': '95',
#   'Hungary': '97',
#   'Iceland': '99',
#   'India': '100',
#   'Indonesia': '101',
#   'Iran (Islamic Republic of)': '102',
#   'Iraq': '103',
#   'Ireland': '104',
#   'Israel': '105',
#   'Italy': '106',
#   'Jamaica': '109',
#   'Japan': '110',
#   'Jordan': '112',
#   'Kazakhstan': '108',
#   'Kenya': '114',
#   'Kiribati': '83',
#   'Kuwait': '118',
#   'Kyrgyzstan': '113',
#   "Lao People's Democratic Republic": '120',
#   'Latvia': '119',
#   'Lebanon': '121',
#   'Lesotho': '122',
#   'Liberia': '123',
#   'Libya': '124',
#   'Lithuania': '126',
#   'Luxembourg': '256',
#   'Madagascar': '129',
#   'Malawi': '130',
#   'Malaysia': '131',
#   'Maldives': '132',
#   'Mali': '133',
#   'Malta': '134',
#   'Marshall Islands': '127',
#   'Mauritania': '136',
#   'Mauritius': '137',
#   'Mexico': '138',
#   'Micronesia (Federated States of)': '145',
#   'Mongolia': '141',
#   'Montenegro': '273',
#   'Morocco': '143',
#   'Mozambique': '144',
#   'Myanmar': '28',
#   'Namibia': '147',
#   'Nauru': '148',
#   'Nepal': '149',
#   'Netherlands (Kingdom of the)': '150',
#   'Netherlands Antilles (former)': '151',
#   'New Caledonia': '153',
#   'New Zealand': '156',
#   'Nicaragua': '157',
#   'Niger': '158',
#   'Nigeria': '159',
#   'North Macedonia': '154',
#   'Norway': '162',
#   'Oman': '221',
#   'Pakistan': '165',
#   'Panama': '166',
#   'Papua New Guinea': '168',
#   'Paraguay': '169',
#   'Peru': '170',
#   'Philippines': '171',
#   'Poland': '173',
#   'Portugal': '174',
#   'Qatar': '179',
#   'Republic of Korea': '117',
#   'Republic of Moldova': '146',
#   'Romania': '183',
#   'Russian Federation': '185',
#   'Rwanda': '184',
#   'Saint Kitts and Nevis': '188',
#   'Saint Lucia': '189',
#   'Saint Vincent and the Grenadines': '191',
#   'Samoa': '244',
#   'Sao Tome and Principe': '193',
#   'Saudi Arabia': '194',
#   'Senegal': '195',
#   'Serbia': '272',
#   'Seychelles': '196',
#   'Sierra Leone': '197',
#   'Slovakia': '199',
#   'Slovenia': '198',
#   'Solomon Islands': '25',
#   'Somalia': '201',
#   'South Africa': '202',
#   'South Sudan': '277',
#   'Spain': '203',
#   'Sri Lanka': '38',
#   'Sudan': '276',
#   'Suriname': '207',
#   'Sweden': '210',
#   'Switzerland': '211',
#   'Syrian Arab Republic': '212',
#   'Tajikistan': '208',
#   'Thailand': '216',
#   'Timor-Leste': '176',
#   'Togo': '217',
#   'Tonga': '219',
#   'Trinidad and Tobago': '220',
#   'Tunisia': '222',
#   'Türkiye': '223',
#   'Turkmenistan': '213',
#   'Tuvalu': '227',
#   'Uganda': '226',
#   'Ukraine': '230',
#   'United Arab Emirates': '225',
#   'United Kingdom of Great Britain and Northern Ireland': '229',
#   'United Republic of Tanzania': '215',
#   'United States of America': '231',
#   'Uruguay': '234',
#   'Uzbekistan': '235',
#   'Vanuatu': '155',
#   'Venezuela (Bolivarian Republic of)': '236',
#   'Viet Nam': '237',
#   'Yemen': '249',
#   'Zambia': '251',
#   'Zimbabwe': '181',
#   'World + (Total)': '5000',
#   'World > (List)': '5000>',
#   'Africa + (Total)': '5100',
#   'Africa > (List)': '5100>',
#   '-- Eastern Africa + (Total)': '5101',
#   '-- Eastern Africa > (List)': '5101>',
#   '-- Middle Africa + (Total)': '5102',
#   '-- Middle Africa > (List)': '5102>',
#   '-- Northern Africa + (Total)': '5103',
#   '-- Northern Africa > (List)': '5103>',
#   '-- Southern Africa + (Total)': '5104',
#   '-- Southern Africa > (List)': '5104>',
#   '-- Western Africa + (Total)': '5105',
#   '-- Western Africa > (List)': '5105>',
#   'Americas + (Total)': '5200',
#   'Americas > (List)': '5200>',
#   '-- Northern America + (Total)': '5203',
#   '-- Northern America > (List)': '5203>',
#   '-- Central America + (Total)': '5204',
#   '-- Central America > (List)': '5204>',
#   '-- Caribbean + (Total)': '5206',
#   '-- Caribbean > (List)': '5206>',
#   '-- South America + (Total)': '5207',
#   '-- South America > (List)': '5207>',
#   'Asia + (Total)': '5300',
#   'Asia > (List)': '5300>',
#   '-- Central Asia + (Total)': '5301',
#   '-- Central Asia > (List)': '5301>',
#   '-- Eastern Asia + (Total)': '5302',
#   '-- Eastern Asia > (List)': '5302>',
#   '-- Southern Asia + (Total)': '5303',
#   '-- Southern Asia > (List)': '5303>',
#   '-- South-eastern Asia + (Total)': '5304',
#   '-- South-eastern Asia > (List)': '5304>',
#   '-- Western Asia + (Total)': '5305',
#   '-- Western Asia > (List)': '5305>',
#   'Europe + (Total)': '5400',
#   'Europe > (List)': '5400>',
#   '-- Eastern Europe + (Total)': '5401',
#   '-- Eastern Europe > (List)': '5401>',
#   '-- Northern Europe + (Total)': '5402',
#   '-- Northern Europe > (List)': '5402>',
#   '-- Southern Europe + (Total)': '5403',
#   '-- Southern Europe > (List)': '5403>',
#   '-- Western Europe + (Total)': '5404',
#   '-- Western Europe > (List)': '5404>',
#   'Oceania + (Total)': '5500',
#   'Oceania > (List)': '5500>',
#   '-- Australia and New Zealand + (Total)': '5501',
#   '-- Australia and New Zealand > (List)': '5501>',
#   '-- Melanesia + (Total)': '5502',
#   '-- Melanesia > (List)': '5502>',
#   '-- Micronesia + (Total)': '5503',
#   '-- Micronesia > (List)': '5503>',
#   '-- Polynesia + (Total)': '5504',
#   '-- Polynesia > (List)': '5504>',
#   'European Union (27) + (Total)': '5707',
#   'European Union (27) > (List)': '5707>',
#   'Least Developed Countries (LDCs) + (Total)': '5801',
#   'Least Developed Countries (LDCs) > (List)': '5801>',
#   'Land Locked Developing Countries (LLDCs) + (Total)': '5802',
#   'Land Locked Developing Countries (LLDCs) > (List)': '5802>',
#   'Small Island Developing States (SIDS) + (Total)': '5803',
#   'Small Island Developing States (SIDS) > (List)': '5803>',
#   'Low Income Food Deficit Countries (LIFDCs) + (Total)': '5815',
#   'Low Income Food Deficit Countries (LIFDCs) > (List)': '5815>',
#   'Net Food Importing Developing Countries (NFIDCs) + (Total)': '5817',
#   'Net Food Importing Developing Countries (NFIDCs) > (List)': '5817>'})

# %% [markdown]
# __Obtain the mediator variables__ <br>
# _FBS (new method) and FBSH (old method)_ <br>
# Items:
# - 'Grand Total + (Total)': '2901',
# - 'Vegetal Products + (Total)': '2903',
# - 'Animal Products + (Total)': '2941'
#
# Elements:
# - 'Total Population - Both sexes': '511'
# - 'Food supply quantity (kg/capita/yr)': '645',
# - 'Food supply (kcal/capita/day)': '664',
# - 'Protein supply quantity (g/capita/day)': '674'
# - 'Fat supply quantity (g/capita/day)': '684'
# - 'Losses': '2120'
#
# _Food Security data_ <br>
# Items: <br>
# - 'Prevalence of undernourishment (percent)': '21004',
# - 'Number of people undernourished (million)': '21001',
# - 'Prevalence of obesity in the adult population (18 years and older) (percent)': '21042',
# - 'Number of obese adults (18 years and older) (million)': '210420',
# - 'Average dietary energy supply adequacy (percent) (3-year average)': '21010',
# - 'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)': '220001',
# - 'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)': '22000',
# - 'Minimum dietary energy requirement  (kcal/cap/day)': '21056',
# - 'Average dietary energy requirement (kcal/cap/day)': '21057' <br>
#
# Elements: <br>
# - 'Value': '6120'
# - 'Confidence interval': '6210'
#
# __Obtain the predictor__ <br>
# Because of API limitations we need to make a separate call for Losses, however API doesn't return all the food items, so we download the data from https://www.fao.org/faostat/en/#data . In case you want to try with API below are the keys. <br>
#
# Items:
# - 'Vegetal Products + (Total)': '2903',
# - 'Vegetal Products > (List)': '2903>',
# - 'Animal Products + (Total)': '2941',
# - 'Animal Products > (List)': '2941>'
#
# Elements:
# - Losses: 2120

# %%
def download_data(area):
    mypars_FBS = {'area': area,
              'element': [511, 2120, 645, 664, 674, 684, 2300],
              'item': [2903, 2901, 2941] ,
              'year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]}
    data_FBS = faostat.get_data_df('FBS', pars=mypars_FBS, strval=False)
    
    mypars_FBSH = {'area': area,
              'element': [511, 2120, 645, 664, 674, 684, 2300],
              'item': [2903, 2901, 2941] ,
              'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]}
    data_FBSH = faostat.get_data_df('FBSH', pars=mypars_FBSH, strval=False)

    mypars_FS = {'area': area,
              'element': [6120, 6210],
              'item': [21004, 21001, 21042, 210420, 21010, 220001, 22000, 21056, 21057] ,
              'year3': [20233, 20223, 20213, 20203, 20193, 20183, 20173, 20163, 20153, 20143, 20133, 20123, 20113, 20103, 20093, 20083, 20073, 20063, 20053, 20043, 20033, 20023, 20013, 20003]}
    data_FS = faostat.get_data_df('FS', pars=mypars_FS, strval=False)
    print("Data has been downloaded.")
    return data_FBS, data_FBSH, data_FS

# %%
# Setting area code for Vietnam
data_FBS, data_FBSH, data_FS = download_data(area = 237)
# Out:
# Data has been downloaded.

# %%
data_FBSH['Element'].value_counts()
# Out:
# Element
# Food supply (kcal/capita/day)             42
# Protein supply quantity (g/capita/day)    42
# Fat supply quantity (g/capita/day)        42
# Name: count, dtype: int64

# %%
data_FS.head(2)
# Out:
#   Domain Code                             Domain  Area Code      Area  \
# 0          FS  Suite of Food Security Indicators        237  Viet Nam
# 1          FS  Suite of Food Security Indicators        237  Viet Nam
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21010
# 1          6121   Value      21010
#
#                                                 Item  Year Code       Year  \
# 0  Average dietary energy supply adequacy (percen...   20002002  2000-2002
# 1  Average dietary energy supply adequacy (percen...   20012003  2001-2003
#
#   Unit  Value
# 0    %  103.0
# 1    %  105.0

# %%
data_FBSH.head(2)
# Out:
#   Domain Code                                             Domain  Area Code  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...        237
# 1        FBSH  Food Balances (-2013, old methodology and popu...        237
#
#        Area  Element Code                        Element  Item Code  \
# 0  Viet Nam           664  Food supply (kcal/capita/day)       2901
# 1  Viet Nam           664  Food supply (kcal/capita/day)       2901
#
#           Item  Year Code  Year        Unit   Value
# 0  Grand Total       2000  2000  kcal/cap/d  2239.0
# 1  Grand Total       2001  2001  kcal/cap/d  2299.0

# %%
data_FBSH.dtypes
# Out:
# Domain Code      object
# Domain           object
# Area Code         int64
# Area             object
# Element Code      int64
# Element          object
# Item Code         int64
# Item             object
# Year Code         int64
# Year             object
# Unit             object
# Value           float64
# dtype: object

# %%
data_FBSH.shape, data_FBS.shape, data_FS.shape
# Out:
# ((126, 12), (117, 12), (206, 12))

# %%
data_FBSH['Year'].unique(), data_FBS['Year'].unique(), data_FS['Year'].unique()
# Out:
# (array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#         '2008', '2009', '2010', '2011', '2012', '2013'], dtype=object),
#  array(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#         '2018', '2019', '2020', '2021', '2022'], dtype=object),
#  array(['2000-2002', '2001-2003', '2002-2004', '2003-2005', '2004-2006',
#         '2005-2007', '2006-2008', '2007-2009', '2008-2010', '2009-2011',
#         '2010-2012', '2011-2013', '2012-2014', '2013-2015', '2014-2016',
#         '2015-2017', '2016-2018', '2017-2019', '2018-2020', '2019-2021',
#         '2020-2022', '2021-2023', '2000', '2001', '2002', '2003', '2004',
#         '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#         '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#         '2021', '2022', '2023'], dtype=object))

# %%
data_FBSH.isna().sum(), data_FBS.isna().sum(), data_FS.isna().sum()
# Out:
# (Domain Code     0
#  Domain          0
#  Area Code       0
#  Area            0
#  Element Code    0
#  Element         0
#  Item Code       0
#  Item            0
#  Year Code       0
#  Year            0
#  Unit            0
#  Value           0
#  dtype: int64,
#  Domain Code     0
#  Domain          0
#  Area Code       0
#  Area            0
#  Element Code    0
#  Element         0
#  Item Code       0
#  Item            0
#  Year Code       0
#  Year            0
#  Unit            0
#  Value           0
#  dtype: int64,
#  Domain Code      0
#  Domain           0
#  Area Code        0
#  Area             0
#  Element Code     0
#  Element          0
#  Item Code        0
#  Item             0
#  Year Code        0
#  Year             0
#  Unit             0
#  Value           22
#  dtype: int64)

# %%
data_FS.loc[data_FS.isnull().any(axis=1)].head(2)
# Out:
#    Domain Code                             Domain  Area Code     Area  \
# 90          FS  Suite of Food Security Indicators         79  Germany
# 91          FS  Suite of Food Security Indicators         79  Germany
#
#     Element Code Element  Item Code  \
# 90          6132   Value     210011
# 91          6132   Value     210011
#
#                                                  Item  Year Code       Year  \
# 90  Number of people undernourished (million) (3-y...   20002002  2000-2002
# 91  Number of people undernourished (million) (3-y...   20012003  2001-2003
#
#           Unit Value
# 90  million No  None
# 91  million No  None

# %%
#Download the datasets
#data_FBSH.to_excel("data_FBSH_gr.xlsx", index=False)
#data_FBS.to_excel("data_FBS_gr.xlsx", index=False)
#data_FS.to_excel("data_FS_gr.xlsx", index=False)

# %% [markdown]
# # Data preprocessing
# - Includes transposing the items/elements for easier processing
# - Deduplication of data
# - Calculation of Total losses per year
# - Merging required columns into one dataset
#
# ## Details
# - FS data has 46 unique Years (3 year + 1 year data) <br>

# %% [markdown]
# # Food item matching
# The Losses Value is provided per different food Items in FAOSTAT, we need to summed those to get the Total Losses per Year.
# We are using two data sources due to the methodology of research changing during the course of time. Thus we will compare two datasets(FBSH and FBS) and check which food Items per year don't match.
#
# **Decision:** We found there are differences in food Items from each methodology (FBS and FBSH). We concluded that the production, and demand for foods can change overtime because of this we have calculated the Total Food Losses value by summing all food Items losses value, regardless if there is mismatch for each year.

# %%
#Load data as this cannot be pulled with API
##Compare two datasets and check which Items (column Item) per year 2011(column Year) don't match.
FBSH_losses = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Vietnam data/FAOSTAT_data_vietam_old.csv')
FBS_losses = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Vietnam data/FAOSTAT_data_vietam_new.csv')
FBS_population = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Vietnam data/FAOSTAT_data_vietnam_population_new.csv')
FBSH_population = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Vietnam data/FAOSTAT_data_vietnam_population_old.csv')

# %%
FBSH_losses['Year'].unique(), FBS_losses['Year'].unique()
# Out:
# (array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#         2011, 2012, 2013]),
#  array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#         2021, 2022]))

# %%
FBSH_losses.shape, FBS_losses.shape
# Out:
# ((392, 14), (506, 15))

# %%
FBS_losses.head(2)
# Out:
#   Domain Code                 Domain  Area Code (M49)      Area  Element Code  \
# 0         FBS  Food Balances (2010-)              704  Viet Nam          5123
# 1         FBS  Food Balances (2010-)              704  Viet Nam          5123
#
#   Element Item Code (FBS)                Item  Year Code  Year    Unit  Value  \
# 0  Losses           S2511  Wheat and products       2010  2010  1000 t     22
# 1  Losses           S2511  Wheat and products       2011  2011  1000 t     24
#
#   Flag Flag Description  Note
# 0    I    Imputed value   NaN
# 1    I    Imputed value   NaN

# %%
FBSH_losses.head(2)
# Out:
#   Domain Code                                             Domain  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...
# 1        FBSH  Food Balances (-2013, old methodology and popu...
#
#    Area Code (M49)      Area  Element Code Element Item Code (FBS)  \
# 0              704  Viet Nam          5123  Losses           S2511
# 1              704  Viet Nam          5123  Losses           S2511
#
#                  Item  Year Code  Year    Unit  Value Flag Flag Description
# 0  Wheat and products       2000  2000  1000 t     11    I    Imputed value
# 1  Wheat and products       2001  2001  1000 t     13    I    Imputed value

# %%
FBSH_losses_2011 = FBSH_losses[FBSH_losses['Year'] == 2011]
FBS_losses_2011 = FBS_losses[FBS_losses['Year'] == 2011]

# Check items in df1 that don't match in df2
items_in_df1_not_in_df2 = FBSH_losses_2011[~FBSH_losses_2011['Item'].isin(FBS_losses_2011['Item'])][['Item','Item Code (FBS)']]

# Check items in df2 that don't match in df1
items_in_df2_not_in_df1 = FBS_losses_2011[~FBS_losses_2011['Item'].isin(FBSH_losses_2011['Item'])][['Item','Item Code (FBS)']]

# Output the results
items_in_df2_not_in_df1
# Out:
#                       Item Item Code (FBS)
# 14       Rice and products           S2807
# 59     Millet and products           S2517
# 130                  Honey           S2745
# 195             Groundnuts           S2552
# 221  Coconuts - Incl Copra           S2560
# 390    Coffee and products           S2630
# 403   Tea (including mate)           S2635
# 416                 Pepper           S2640
# 442          Spices, Other           S2645
# 455         Offals, Edible           S2736
# 468     Fats, Animals, Raw           S2737
# 481                   Eggs           S2744

# %%
items_in_df1_not_in_df2
# Out:
#                          Item Item Code (FBS)
# 25   Rice (Milled Equivalent)           S2805
# 179   Groundnuts (Shelled Eq)           S2556

# %% [markdown]
# # Deduplicate data
# For some countries (example with Bulgaria) we noticed there are duplicated Items per year because of two reasons:
# - The same Item has I (Imputed by receiver agency) and E (Estimated value) flag _(see below the definitions)_ - FBSH data, year 2011, S2949 Eggs, S2744	 Eggs
# - Two Items with similar names, seemingly including the other - FBSH data, year 2011, S2911	Pulses, S2549	Pulses, Other and products
# - **Decision**: Choose flag I, because all of the food items in FBS are with flag I, possibly the Estimated values aren't conclusive.
#
# FAO definitions of flags I and E: <br>
# <br>
# __E - Estimated value__ - Observation obtained through an estimation methodology or based on the use of a limited amount of data (e.g. to produce a value at an early stage of the production stage while not all data are available). If needed, additional information can be provided through free text using the COMMENT_OBS attribute at the observation level or at a higher level (in SDMX-compliant environment). This code is also to be used when the estimation is done by a sender agency (and flagged as such). When the imputation is carried out by a receiver agency in order to replace or fill gaps in reported data series, the flag to use is I “Value imputed by a receiving agency”. <br>
# __I - Value imputed by a receiving agency__ Observation imputed by a receiving agency to replace or fill gaps in reported data series. This code is intended to cover all cases where a receiving agency publishes data about a sending agency that do not come from an official source in the sender agency's reporting framework. When the estimation is done by the sender agency, the flag to use is E “Estimated value”.

# %%
FBSH_losses.loc[(FBSH_losses['Year'] == 2011) & (FBSH_losses['Item'] == 'Eggs')]
# Out:
# Empty DataFrame
# Columns: [Domain Code, Domain, Area Code (M49), Area, Element Code, Element, Item Code (FBS), Item, Year Code, Year, Unit, Value, Flag, Flag Description]
# Index: []

# %%
FBSH_losses['Flag'].value_counts()
# Out:
# Flag
# I    392
# Name: count, dtype: int64

# %%
FBS_losses['Flag'].value_counts()
# Out:
# Flag
# I    506
# Name: count, dtype: int64

# %% [markdown]
# # Sum Losses per Item

# %%
def preprocessing(FBSH_losses_data, FBS_losses_data, FBSH_population, FBS_population, data_FBS, data_FBSH, data_FS):
    df_sorted_FSBH = FBSH_losses.sort_values(by=['Year', 'Item', 'Flag'], ascending=[True, True, False])

    # Drop duplicates, keeping the first (which will be 'I' if it exists)
    FBSH_losses_d = df_sorted_FSBH.drop_duplicates(subset=['Year', 'Item'], keep='first')

    total_losses_per_year_FBSH = FBSH_losses_d.groupby('Year')['Value'].sum().reset_index()
    total_losses_per_year_FBSH = total_losses_per_year_FBSH.rename(columns={'Value': 'Total Losses (1000 t)'})
    
    total_losses_per_year_FBS = FBS_losses.groupby('Year')['Value'].sum().reset_index()
    total_losses_per_year_FBS = total_losses_per_year_FBS.rename(columns={'Value': 'Total Losses (1000 t)'})
    
    # Merge the total losses back to the original df based on Year
    FBSH_losses_sum = pd.merge(FBSH_losses_d, total_losses_per_year_FBSH, on='Year', how='left')
    FBS_losses_sum = pd.merge(FBS_losses, total_losses_per_year_FBS, on='Year', how='left')

    # Drop unnecessary columns
    FBSH_losses_sum_reduced = FBSH_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')
    FBS_losses_sum_reduced = FBS_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')
    
    # Drop duplicate years, keeping the first occurrence
    FBSH_losses_sum_reduced = FBSH_losses_sum_reduced.drop_duplicates(subset='Year')
    FBS_losses_sum_reduced = FBS_losses_sum_reduced.drop_duplicates(subset='Year')

    # Prep final datasets
    # Pivot the FS table
    pivoted_FS = data_FS.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year'],
        columns='Item',
        values='Value',
        aggfunc='first'
    ).reset_index()

    #Pivot the FBSH table
    # Merge Total Losses (1000 t) to the rest of the data
    data_FBSH['Year'] = data_FBSH['Year'].astype(int)
    data_FBSH = pd.merge( data_FBSH, FBSH_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')
    
    # Create a combined column for Element + Item
    data_FBSH['Element_Item'] = data_FBSH['Element'] + "_" + data_FBSH['Item']
    
    # Pivot the table
    pivoted_FBSH = data_FBSH.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
        columns='Element_Item',
        values='Value',
        aggfunc='first'
    ).reset_index()

    #Pivot the FBS table
    # Merge Total Losses (1000 t) to the rest of the data
    data_FBS['Year'] = data_FBS['Year'].astype(int)
    data_FBS = pd.merge( data_FBS, FBS_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')
    
    # Create a combined column for Element + Item
    data_FBS['Element_Item'] = data_FBS['Element'] + "_" + data_FBS['Item']
    
    # Pivot the table
    pivoted_FBS = data_FBS.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
        columns='Element_Item',
        values='Value',
        aggfunc='first'
    ).reset_index()
    
    pivoted_FBS = pd.merge(pivoted_FBS, FBS_population[['Year', 'Value']], on='Year', how='left')
    pivoted_FBSH = pd.merge(pivoted_FBSH, FBSH_population[['Year', 'Value']], on='Year', how='left')
 
    #Total Losses (g/cap/day) = Total Losses (1000t) * 1000000g / Population (1000m) / 365 days of the year
    pivoted_FBS['Total Losses (g/cap/day)'] = ((pivoted_FBS['Total Losses (1000 t)']*1000000)/pivoted_FBS['Value']/365).round()
    pivoted_FBSH['Total Losses (g/cap/day)'] = ((pivoted_FBSH['Total Losses (1000 t)']*1000000)/pivoted_FBSH['Value']/365).round()

    #Drop duplicate years
    years_to_drop = [2010, 2011, 2012, 2013]
    pivoted_FBSH = pivoted_FBSH[~pivoted_FBSH['Year'].isin(years_to_drop)]

    #Concat datasets
    pivoted_FBS = pivoted_FBS[pivoted_FBSH.columns]
    final_1y = pd.concat([pivoted_FBSH, pivoted_FBS], ignore_index=True)
    final_1y.rename(columns={'Value': 'Population (1000no)'}, inplace=True)

    #Merge FS to FBS and FBSH datasets - 1 year aggregations features only (3y features are NAN)
    columns_to_merge = ['Year Code', 'Average dietary energy requirement (kcal/cap/day)',
       #'Average dietary energy supply adequacy (percent) (3-year average)',
       'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)',
       #'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)',
       'Minimum dietary energy requirement  (kcal/cap/day)',
       'Number of obese adults (18 years and older) (million)',
       'Prevalence of obesity in the adult population (18 years and older) (percent)']
       #'Prevalence of undernourishment (percent) (3-year average)']
    
    FS_selected = pivoted_FS[columns_to_merge]
    final_1y = pd.merge(final_1y, FS_selected, on='Year Code', how='inner')

    #Turn the object data types into numeric
    final_1y[columns_to_merge] = final_1y[columns_to_merge].astype('float')
    
    #Calculate 3 year averages for merged_1y, sort rows
    final_1y = final_1y.sort_values("Year Code").reset_index(drop=True)

    # Columns to exclude from moving average
    exclude_cols = ["Area", "Area Code", "Year", "Year Code"]
    
    # Identify numeric columns to apply moving average
    numeric_cols = final_1y.select_dtypes(include='number').columns.difference(exclude_cols)
    
    # Apply the moving average
    df_ma = final_1y.copy()
    df_ma[numeric_cols] = (
        final_1y[numeric_cols]
        .rolling(window=3, center=False, min_periods=3)
        .mean()
        .round()
    )
    
    # Map Year Code from 3yr FS dataset to later merge the dependent variables to FBS/FBSH data
    df_ma["Year Code"] = df_ma["Year Code"].replace({
    2002: 20002002,
    2003: 20012003,
    2004: 20022004,
    2005: 20032005,
    2006: 20042006,
    2007: 20052007,
    2008: 20062008,
    2009: 20072009,
    2010: 20082010,
    2011: 20092011,
    2012: 20102012,
    2013: 20112013,
    2014: 20122014,
    2015: 20132015,
    2016: 20142016,
    2017: 20152017,
    2018: 20162018,
    2019: 20172019,
    2020: 20182020,
    2021: 20192021,
    2022: 20202022,
    })

    df_ma = pd.merge(
        df_ma,
        pivoted_FS[['Year Code',
                    'Average dietary energy supply adequacy (percent) (3-year average)',
                    'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)',
                    'Prevalence of undernourishment (percent) (3-year average)']],  # only matching 'Year Code' used to filter
        on='Year Code',
        how='inner'
        )

    #Drop the years that can't have a 3yr average
    final_3y = df_ma[~df_ma['Year'].isin([2000, 2001])]

    # Replace '<2.5' with '2.5', then convert to float
    #final_3y['Prevalence of undernourishment (percent) (3-year average)'] = final_3y['Prevalence of undernourishment (percent) (3-year average)'].astype(str).str.replace(r'^[<>]\s*', '', regex=True).astype(float)

    final_3y.loc[:, 'Prevalence of undernourishment (percent) (3-year average)'] = (
    final_3y['Prevalence of undernourishment (percent) (3-year average)']
    .astype(str)
    .str.replace(r'^[<>]\s*', '', regex=True)
    .astype(float)
    )

    return pivoted_FS, pivoted_FBS, pivoted_FBSH, final_1y, final_3y

# %%
fs, fbs, fbsh, final_1y, final_3y = preprocessing(FBSH_losses, FBS_losses, FBSH_population, FBS_population, data_FBS, data_FBSH, data_FS)

# %%
final_1y.shape, final_3y.shape
# Out:
# ((23, 23), (21, 26))

# %%
final_1y.shape, final_3y.shape
# Out:
# ((23, 23), (21, 26))

# %%
final_1y.head(2)
# Out:
#   Domain Code                                             Domain  Area Code  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...        237
# 1        FBSH  Food Balances (-2013, old methodology and popu...        237
#
#        Area  Year Code  Year  Total Losses (1000 t)  \
# 0  Viet Nam     2000.0  2000                   4019
# 1  Viet Nam     2001.0  2001                   4189
#
#    Fat supply quantity (g/capita/day)_Animal Products  \
# 0                                              22.33
# 1                                              24.26
#
#    Fat supply quantity (g/capita/day)_Grand Total  \
# 0                                           38.69
# 1                                           41.76
#
#    Fat supply quantity (g/capita/day)_Vegetal Products  ...  \
# 0                                              16.36    ...
# 1                                              17.50    ...
#
#    Protein supply quantity (g/capita/day)_Animal Products  \
# 0                                              15.36
# 1                                              15.94
#
#    Protein supply quantity (g/capita/day)_Grand Total  \
# 0                                              54.84
# 1                                              56.63
#
#    Protein supply quantity (g/capita/day)_Vegetal Products  \
# 0                                              39.48
# 1                                              40.68
#
#    Population (1000no)  Total Losses (g/cap/day)  \
# 0              80888.0                     136.0
# 1              81729.0                     140.0
#
#    Average dietary energy requirement (kcal/cap/day)  \
# 0                                             2245.0
# 1                                             2256.0
#
#    Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)  \
# 0                                             2266.0
# 1                                             2327.0
#
#    Minimum dietary energy requirement  (kcal/cap/day)  \
# 0                                             1739.0
# 1                                             1746.0
#
#    Number of obese adults (18 years and older) (million)  \
# 0                                                0.1
# 1                                                0.2
#
#    Prevalence of obesity in the adult population (18 years and older) (percent)
# 0                                                0.3
# 1                                                0.3
#
# [2 rows x 23 columns]

# %%
final_3y.head(2)
# Out:
#   Domain Code                                             Domain  Area Code  \
# 2        FBSH  Food Balances (-2013, old methodology and popu...        237
# 3        FBSH  Food Balances (-2013, old methodology and popu...        237
#
#        Area   Year Code  Year  Total Losses (1000 t)  \
# 2  Viet Nam  20002002.0  2002                 4282.0
# 3  Viet Nam  20012003.0  2003                 4526.0
#
#    Fat supply quantity (g/capita/day)_Animal Products  \
# 2                                               24.0
# 3                                               26.0
#
#    Fat supply quantity (g/capita/day)_Grand Total  \
# 2                                            42.0
# 3                                            44.0
#
#    Fat supply quantity (g/capita/day)_Vegetal Products  ...  \
# 2                                               17.0    ...
# 3                                               18.0    ...
#
#    Population (1000no)  Total Losses (g/cap/day)  \
# 2              81722.0                     143.0
# 3              82543.0                     150.0
#
#    Average dietary energy requirement (kcal/cap/day)  \
# 2                                             2255.0
# 3                                             2265.0
#
#    Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)  \
# 2                                             2327.0
# 3                                             2388.0
#
#    Minimum dietary energy requirement  (kcal/cap/day)  \
# 2                                             1746.0
# 3                                             1752.0
#
#    Number of obese adults (18 years and older) (million)  \
# 2                                                0.0
# 3                                                0.0
#
#    Prevalence of obesity in the adult population (18 years and older) (percent)  \
# 2                                                0.0
# 3                                                0.0
#
#    Average dietary energy supply adequacy (percent) (3-year average)  \
# 2                                              103.0
# 3                                              105.0
#
#    Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)  \
# 2                                             2328.0
# 3                                             2388.0
#
#    Prevalence of undernourishment (percent) (3-year average)
# 2                                               19.5
# 3                                               17.7
#
# [2 rows x 26 columns]

# %%
final_3y.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year',
#        'Total Losses (1000 t)',
#        'Fat supply quantity (g/capita/day)_Animal Products',
#        'Fat supply quantity (g/capita/day)_Grand Total',
#        'Fat supply quantity (g/capita/day)_Vegetal Products',
#        'Food supply (kcal/capita/day)_Animal Products',
#        'Food supply (kcal/capita/day)_Grand Total',
#        'Food supply (kcal/capita/day)_Vegetal Products',
#        'Protein supply quantity (g/capita/day)_Animal Products',
#        'Protein supply quantity (g/capita/day)_Grand Total',
#        'Protein supply quantity (g/capita/day)_Vegetal Products',
#        'Population (1000no)', 'Total Losses (g/cap/day)',
#        'Average dietary energy requirement (kcal/cap/day)',
#        'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)',
#        'Minimum dietary energy requirement  (kcal/cap/day)',
#        'Number of obese adults (18 years and older) (million)',
#        'Prevalence of obesity in the adult population (18 years and older) (percent)',
#        'Average dietary energy supply adequacy (percent) (3-year average)',
#        'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)',
#        'Prevalence of undernourishment (percent) (3-year average)'],
#       dtype='object')

# %%
mi

# %%
final_3y.head(2)
# Out:
#   Domain Code                                             Domain  Area Code  \
# 2        FBSH  Food Balances (-2013, old methodology and popu...         79
# 3        FBSH  Food Balances (-2013, old methodology and popu...         79
#
#       Area   Year Code  Year  Total Losses (1000 t)  \
# 2  Germany  20002002.0  2002                 3633.0
# 3  Germany  20012003.0  2003                 3313.0
#
#    Fat supply quantity (g/capita/day)_Animal Products  \
# 2                                               81.0
# 3                                               82.0
#
#    Fat supply quantity (g/capita/day)_Grand Total  \
# 2                                           140.0
# 3                                           138.0
#
#    Fat supply quantity (g/capita/day)_Vegetal Products  ...  \
# 2                                               59.0    ...
# 3                                               57.0    ...
#
#    Population (1000no)  Total Losses (g/cap/day)  \
# 2              83593.0                     119.0
# 3              83685.0                     109.0
#
#    Average dietary energy requirement (kcal/cap/day)  \
# 2                                             2542.0
# 3                                             2543.0
#
#    Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)  \
# 2                                             3464.0
# 3                                             3483.0
#
#    Minimum dietary energy requirement  (kcal/cap/day)  \
# 2                                             1957.0
# 3                                             1958.0
#
#    Number of obese adults (18 years and older) (million)  \
# 2                                               12.0
# 3                                               12.0
#
#    Prevalence of obesity in the adult population (18 years and older) (percent)  \
# 2                                               18.0
# 3                                               19.0
#
#    Average dietary energy supply adequacy (percent) (3-year average)  \
# 2                                                136
# 3                                                137
#
#    Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)  \
# 2                                               3464
# 3                                               3483
#
#    Prevalence of undernourishment (percent) (3-year average)
# 2                                                2.5
# 3                                                2.5
#
# [2 rows x 26 columns]

# %%
#Download the edited datasets
final_1y.to_csv("final_1y_vietnam.csv", index=False)
final_3y.to_csv("final_3y_vietnam.csv", index=False)

# %% [markdown]
# # Data exploration
# # Data visualization

# %%
#compare different countries values through the years(line chart)
#distribution of each country?
