# %%
import pandas as pd
import faostat
import openpyxl

# %% [markdown]
# # Modeling Task
# Analyze how food waste relates to each of the following three target nutrition indicators (with potential mediation by per-capita food supply):
#
# - Dietary Energy Adequacy – The average dietary energy supply as a percentage of the population’s required energy needs.
# - Prevalence of Undernourishment – The share of the population that is chronically undernourished (consuming less than the minimum dietary energy requirement).
# - Prevalence of Obesity – The share of the adult population that is obese (BMI ≥ 30).
# <br>Mediating Factor: Food Supply per Capita – The average food availability per person, measured in kilocalories per person per day.
#
# Countries for Analysis
# | Region/Type         | Country  | Rationale                                                  |
# |---------------------|----------|-------------------------------------------------------------|
# | EU (mandatory)      | Bulgaria | Transitioning food system, moderate waste issues            |
# | High-income EU      | France   | Adequate diets, active waste-reduction policies             |
# | High-income EU      | Germany  | High surplus, distinct obesity profile                      |
# | Sub-Saharan Africa  | Nigeria  | High undernourishment, post-harvest losses                  |
# | South Asia          | India    | Large undernourished population, growing obesity            |
# | Latin America       | Brazil   | Rising obesity, emerging economy                            |
# | North America       | USA      | Very high obesity & waste, low hunger                       |
# | MENA                | Egypt    | High obesity, import-reliant, food insecurity               |
# | Southeast Asia      | Vietnam  | Rapid dietary shift, changing waste patterns                |
# | Latin America       | Mexico   | Obesity crisis, notable waste                               |

# %% [markdown]
# # Data download
# Downloading the data from Faostat API
#
# Datasets: <br>
# - FBSH - Food Balances (-2013, old methodology and population)
# - FBS - Food Balances (2010-)
# - FS - Suite of Food Security Indicators - dependent variables are here

# %%
#faostat.list_datasets()

# %%
#faostat.list_pars('FBS'), faostat.list_pars('FBSH'), faostat.list_pars('FS')

# %%
#Obtain the code for required features
#faostat.get_par('FS', 'element'), faostat.get_par('FS', 'items'), faostat.get_par('FS', 'area'), faostat.get_par('FS', 'year3')

# %%
#faostat.get_par('FBSH', 'element'), faostat.get_par('FBSH', 'itemsagg'), faostat.get_par('FBSH', 'items'), faostat.get_par('FBSH', 'area')

# %%
#faostat.get_par('FBS', 'element'), faostat.get_par('FBS', 'itemsagg'), faostat.get_par('FBS', 'items'), faostat.get_par('FBS', 'area')

# %% [markdown]
# __Obtain the mediator variables__ <br>
# _FBS (new method) and FBSH (old method)_ <br>
# Items:
# - 'Grand Total + (Total)': '2901',
# - 'Vegetal Products + (Total)': '2903',
# - 'Animal Products + (Total)': '2941'
#
# Elements:
# - 'Total Population - Both sexes': '511'
# - 'Food supply quantity (kg/capita/yr)': '645',
# - 'Food supply (kcal/capita/day)': '664',
# - 'Protein supply quantity (g/capita/day)': '674'
# - 'Fat supply quantity (g/capita/day)': '684'
# - 'Losses': '2120'
#
# _Food Security data_ <br>
# Items: <br>
# - 'Prevalence of undernourishment (percent)': '21004',
# - 'Number of people undernourished (million)': '21001',
# - 'Prevalence of obesity in the adult population (18 years and older) (percent)': '21042',
# - 'Number of obese adults (18 years and older) (million)': '210420',
# - 'Average dietary energy supply adequacy (percent) (3-year average)': '21010',
# - 'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)': '220001',
# - 'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)': '22000',
# - 'Minimum dietary energy requirement  (kcal/cap/day)': '21056',
# - 'Average dietary energy requirement (kcal/cap/day)': '21057' <br>
#
# Elements: <br>
# - 'Value': '6120'
# - 'Confidence interval': '6210'
#
# __Obtain the predictor__ <br>
# Because of API limitations we need to make a separate call for Losses, however API doesn't return all the food items, so we download the data from https://www.fao.org/faostat/en/#data . In case you want to try with API below are the keys. <br>
#
# Items:
# - 'Vegetal Products + (Total)': '2903',
# - 'Vegetal Products > (List)': '2903>',
# - 'Animal Products + (Total)': '2941',
# - 'Animal Products > (List)': '2941>'
#
# Elements:
# - Losses: 2120

# %%
def download_data(area):
    mypars_FBS = {'area': area,
              'element': [511, 2120, 645, 664, 674, 684, 2300],
              'item': [2903, 2901, 2941] ,
              'year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]}
    data_FBS = faostat.get_data_df('FBS', pars=mypars_FBS, strval=False)
    
    mypars_FBSH = {'area': area,
              'element': [511, 2120, 645, 664, 674, 684, 2300],
              'item': [2903, 2901, 2941] ,
              'year': [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]}
    data_FBSH = faostat.get_data_df('FBSH', pars=mypars_FBSH, strval=False)

    mypars_FS = {'area': area,
              'element': [6120, 6210],
              'item': [21004, 21001, 21042, 210420, 21010, 220001, 22000, 21056, 21057] ,
              'year3': [20233, 20223, 20213, 20203, 20193, 20183, 20173, 20163, 20153, 20143, 20133, 20123, 20113, 20103, 20093, 20083, 20073, 20063, 20053, 20043, 20033, 20023, 20013, 20003]}
    data_FS = faostat.get_data_df('FS', pars=mypars_FS, strval=False)
    print("Data has been downloaded.")
    return data_FBS, data_FBSH, data_FS

# %%
# Setting area code for Germany - 79
data_FBS, data_FBSH, data_FS = download_data(area = 79)
# Out:
# Data has been downloaded.

# %%
data_FS.head(2)
# Out:
#   Domain Code                             Domain  Area Code     Area  \
# 0          FS  Suite of Food Security Indicators         79  Germany
# 1          FS  Suite of Food Security Indicators         79  Germany
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21010
# 1          6121   Value      21010
#
#                                                 Item  Year Code       Year  \
# 0  Average dietary energy supply adequacy (percen...   20002002  2000-2002
# 1  Average dietary energy supply adequacy (percen...   20012003  2001-2003
#
#   Unit Value
# 0    %   136
# 1    %   137

# %%
data_FBSH['Element'].value_counts()
# Out:
# Element
# Food supply (kcal/capita/day)             42
# Protein supply quantity (g/capita/day)    42
# Fat supply quantity (g/capita/day)        42
# Name: count, dtype: int64

# %%
data_FS.head(2)
# Out:
#   Domain Code                             Domain  Area Code     Area  \
# 0          FS  Suite of Food Security Indicators         79  Germany
# 1          FS  Suite of Food Security Indicators         79  Germany
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21010
# 1          6121   Value      21010
#
#                                                 Item  Year Code       Year  \
# 0  Average dietary energy supply adequacy (percen...   20002002  2000-2002
# 1  Average dietary energy supply adequacy (percen...   20012003  2001-2003
#
#   Unit Value
# 0    %   136
# 1    %   137

# %%
data_FBSH.head(2)
# Out:
#   Domain Code                                             Domain  Area Code  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...         79
# 1        FBSH  Food Balances (-2013, old methodology and popu...         79
#
#       Area  Element Code                        Element  Item Code  \
# 0  Germany           664  Food supply (kcal/capita/day)       2901
# 1  Germany           664  Food supply (kcal/capita/day)       2901
#
#           Item  Year Code  Year        Unit   Value
# 0  Grand Total       2000  2000  kcal/cap/d  3336.0
# 1  Grand Total       2001  2001  kcal/cap/d  3363.0

# %%
data_FBSH.dtypes
# Out:
# Domain Code      object
# Domain           object
# Area Code         int64
# Area             object
# Element Code      int64
# Element          object
# Item Code         int64
# Item             object
# Year Code         int64
# Year             object
# Unit             object
# Value           float64
# dtype: object

# %%
data_FBSH.shape, data_FBS.shape, data_FS.shape
# Out:
# ((126, 12), (117, 12), (206, 12))

# %%
data_FBSH['Year'].unique(), data_FBS['Year'].unique(), data_FS['Year'].unique()
# Out:
# (array(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#         '2008', '2009', '2010', '2011', '2012', '2013'], dtype=object),
#  array(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#         '2018', '2019', '2020', '2021', '2022'], dtype=object),
#  array(['2000-2002', '2001-2003', '2002-2004', '2003-2005', '2004-2006',
#         '2005-2007', '2006-2008', '2007-2009', '2008-2010', '2009-2011',
#         '2010-2012', '2011-2013', '2012-2014', '2013-2015', '2014-2016',
#         '2015-2017', '2016-2018', '2017-2019', '2018-2020', '2019-2021',
#         '2020-2022', '2021-2023', '2000', '2001', '2002', '2003', '2004',
#         '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#         '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020',
#         '2021', '2022', '2023'], dtype=object))

# %%
data_FBSH.isna().sum(), data_FBS.isna().sum(), data_FS.isna().sum()
# Out:
# (Domain Code     0
#  Domain          0
#  Area Code       0
#  Area            0
#  Element Code    0
#  Element         0
#  Item Code       0
#  Item            0
#  Year Code       0
#  Year            0
#  Unit            0
#  Value           0
#  dtype: int64,
#  Domain Code     0
#  Domain          0
#  Area Code       0
#  Area            0
#  Element Code    0
#  Element         0
#  Item Code       0
#  Item            0
#  Year Code       0
#  Year            0
#  Unit            0
#  Value           0
#  dtype: int64,
#  Domain Code      0
#  Domain           0
#  Area Code        0
#  Area             0
#  Element Code     0
#  Element          0
#  Item Code        0
#  Item             0
#  Year Code        0
#  Year             0
#  Unit             0
#  Value           22
#  dtype: int64)

# %%
data_FS.loc[data_FS.isnull().any(axis=1)].head(2)
# Out:
#    Domain Code                             Domain  Area Code     Area  \
# 90          FS  Suite of Food Security Indicators         79  Germany
# 91          FS  Suite of Food Security Indicators         79  Germany
#
#     Element Code Element  Item Code  \
# 90          6132   Value     210011
# 91          6132   Value     210011
#
#                                                  Item  Year Code       Year  \
# 90  Number of people undernourished (million) (3-y...   20002002  2000-2002
# 91  Number of people undernourished (million) (3-y...   20012003  2001-2003
#
#           Unit Value
# 90  million No  None
# 91  million No  None

# %%
#Download the datasets
#data_FBSH.to_excel("data_FBSH_gr.xlsx", index=False)
#data_FBS.to_excel("data_FBS_gr.xlsx", index=False)
#data_FS.to_excel("data_FS_gr.xlsx", index=False)

# %% [markdown]
# # Data preprocessing
# - Includes transposing the items/elements for easier processing
# - Deduplication of data
# - Calculation of Total losses per year
# - Merging required columns into one dataset
#
# ## Details
# - FS data has 46 unique Years (3 year + 1 year data) <br>

# %% [markdown]
# # Food item matching
# The Losses Value is provided per different food Items in FAOSTAT, we need to summed those to get the Total Losses per Year.
# We are using two data sources due to the methodology of research changing during the course of time. Thus we will compare two datasets(FBSH and FBS) and check which food Items per year don't match.
#
# **Decision:** We found there are differences in food Items from each methodology (FBS and FBSH). We concluded that the production, and demand for foods can change overtime because of this we have calculated the Total Food Losses value by summing all food Items losses value, regardless if there is mismatch for each year.

# %%
#Load data as this cannot be pulled with API
##Compare two datasets and check which Items (column Item) per year 2011(column Year) don't match.
FBSH_losses = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Germany data/FAOSTAT_data_old_gr.csv')
FBS_losses = pd.read_csv('/Users/aysun/Documents/fao-nutrition/Germany data/FAOSTAT_data_new_gr.csv')

# %%
FBSH_losses['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013])

# %%
FBSH_losses.shape, FBS_losses.shape
# Out:
# ((518, 14), (521, 15))

# %%
FBS_losses.head(2)
# Out:
#   Domain Code                 Domain  Area Code (M49)     Area  Element Code  \
# 0         FBS  Food Balances (2010-)              276  Germany          5123
# 1         FBS  Food Balances (2010-)              276  Germany          5123
#
#   Element Item Code (FBS)                Item  Year Code  Year    Unit  Value  \
# 0  Losses           S2511  Wheat and products       2010  2010  1000 t    638
# 1  Losses           S2511  Wheat and products       2011  2011  1000 t    614
#
#   Flag Flag Description  Note
# 0    I    Imputed value   NaN
# 1    I    Imputed value   NaN

# %%
FBSH_losses.head(2)
# Out:
#   Domain Code                                             Domain  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...
# 1        FBSH  Food Balances (-2013, old methodology and popu...
#
#    Area Code (M49)     Area  Element Code Element Item Code (FBS)  \
# 0              276  Germany          5123  Losses           S2511
# 1              276  Germany          5123  Losses           S2511
#
#                  Item  Year Code  Year    Unit  Value Flag Flag Description
# 0  Wheat and products       2000  2000  1000 t    521    I    Imputed value
# 1  Wheat and products       2001  2001  1000 t    550    I    Imputed value

# %%
FBSH_losses_2011 = FBSH_losses[FBSH_losses['Year'] == 2011]
FBS_losses_2011 = FBS_losses[FBS_losses['Year'] == 2011]

# Check items in df1 that don't match in df2
items_in_df1_not_in_df2 = FBSH_losses_2011[~FBSH_losses_2011['Item'].isin(FBS_losses_2011['Item'])][['Item','Item Code (FBS)']]

# Check items in df2 that don't match in df1
items_in_df2_not_in_df1 = FBS_losses_2011[~FBS_losses_2011['Item'].isin(FBSH_losses_2011['Item'])][['Item','Item Code (FBS)']]

# Output the results
items_in_df2_not_in_df1
# Out:
#                   Item Item Code (FBS)
# 14   Rice and products           S2807
# 71      Cereals, other           S2520
# 184         Groundnuts           S2552

# %%
items_in_df1_not_in_df2
# Out:
#                          Item Item Code (FBS)
# 25   Rice (Milled Equivalent)           S2805
# 95             Cereals, Other           S2520
# 193   Groundnuts (Shelled Eq)           S2556

# %% [markdown]
# # Deduplicate data
# For some countries (example with Bulgaria) we noticed there are duplicated Items per year because of two reasons:
# - The same Item has I (Imputed by receiver agency) and E (Estimated value) flag _(see below the definitions)_ - FBSH data, year 2011, S2949 Eggs, S2744	 Eggs
# - Two Items with similar names, seemingly including the other - FBSH data, year 2011, S2911	Pulses, S2549	Pulses, Other and products
# - **Decision**: Choose flag I, because all of the food items in FBS are with flag I, possibly the Estimated values aren't conclusive.
#
# FAO definitions of flags I and E: <br>
# <br>
# __E - Estimated value__ - Observation obtained through an estimation methodology or based on the use of a limited amount of data (e.g. to produce a value at an early stage of the production stage while not all data are available). If needed, additional information can be provided through free text using the COMMENT_OBS attribute at the observation level or at a higher level (in SDMX-compliant environment). This code is also to be used when the estimation is done by a sender agency (and flagged as such). When the imputation is carried out by a receiver agency in order to replace or fill gaps in reported data series, the flag to use is I “Value imputed by a receiving agency”. <br>
# __I - Value imputed by a receiving agency__ Observation imputed by a receiving agency to replace or fill gaps in reported data series. This code is intended to cover all cases where a receiving agency publishes data about a sending agency that do not come from an official source in the sender agency's reporting framework. When the estimation is done by the sender agency, the flag to use is E “Estimated value”.

# %%
FBSH_losses.loc[(FBSH_losses['Year'] == 2011) & (FBSH_losses['Item'] == 'Eggs')]
# Out:
#     Domain Code                                             Domain  \
# 501        FBSH  Food Balances (-2013, old methodology and popu...
#
#      Area Code (M49)     Area  Element Code Element Item Code (FBS)  Item  \
# 501              276  Germany          5123  Losses           S2744  Eggs
#
#      Year Code  Year    Unit  Value Flag Flag Description
# 501       2011  2011  1000 t      7    I    Imputed value

# %%
FBSH_losses['Flag'].value_counts()
# Out:
# Flag
# I    518
# Name: count, dtype: int64

# %%
FBS_losses['Flag'].value_counts()
# Out:
# Flag
# I    521
# Name: count, dtype: int64

# %%
df_sorted_FSBH = FBSH_losses.sort_values(by=['Year', 'Item', 'Flag'], ascending=[True, True, False])

# Drop duplicates, keeping the first (which will be 'I' if it exists)
FBSH_losses_d = df_sorted_FSBH.drop_duplicates(subset=['Year', 'Item'], keep='first')
FBSH_losses_d['Flag'].value_counts()
# Out:
# Flag
# I    518
# Name: count, dtype: int64

# %% [markdown]
# # Sum Losses per Item

# %%
def preprocessing(FBSH_losses_data, FBS_losses_data, data_FBS, data_FBSH, data_FS):
    df_sorted_FSBH = FBSH_losses.sort_values(by=['Year', 'Item', 'Flag'], ascending=[True, True, False])

    # Drop duplicates, keeping the first (which will be 'I' if it exists)
    FBSH_losses_d = df_sorted_FSBH.drop_duplicates(subset=['Year', 'Item'], keep='first')

    total_losses_per_year_FBSH = FBSH_losses_d.groupby('Year')['Value'].sum().reset_index()
    total_losses_per_year_FBSH = total_losses_per_year_FBSH.rename(columns={'Value': 'Total Losses (1000 t)'})
    
    total_losses_per_year_FBS = FBS_losses.groupby('Year')['Value'].sum().reset_index()
    total_losses_per_year_FBS = total_losses_per_year_FBS.rename(columns={'Value': 'Total Losses (1000 t)'})
    
    # Merge the total losses back to the original df based on Year
    FBSH_losses_sum = pd.merge(FBSH_losses_d, total_losses_per_year_FBSH, on='Year', how='left')
    FBS_losses_sum = pd.merge(FBS_losses, total_losses_per_year_FBS, on='Year', how='left')

    # Drop unnecessary columns
    FBSH_losses_sum_reduced = FBSH_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')
    FBS_losses_sum_reduced = FBS_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')
    
    # Drop duplicate years, keeping the first occurrence
    FBSH_losses_sum_reduced = FBSH_losses_sum_reduced.drop_duplicates(subset='Year')
    FBS_losses_sum_reduced = FBS_losses_sum_reduced.drop_duplicates(subset='Year')

    # Prep final datasets
    # Pivot the FS table
    pivoted_FS = data_FS.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year'],
        columns='Item',
        values='Value',
        aggfunc='first'
    ).reset_index()

    #Pivot the FBSH table
    # Merge Total Losses (1000 t) to the rest of the data
    data_FBSH['Year'] = data_FBSH['Year'].astype(int)
    data_FBSH = pd.merge( data_FBSH, FBSH_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')
    
    # Create a combined column for Element + Item
    data_FBSH['Element_Item'] = data_FBSH['Element'] + "_" + data_FBSH['Item']
    
    # Pivot the table
    pivoted_FBSH = data_FBSH.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
        columns='Element_Item',
        values='Value',
        aggfunc='first'
    ).reset_index()

    #Pivot the FBS table
    # Merge Total Losses (1000 t) to the rest of the data
    data_FBS['Year'] = data_FBS['Year'].astype(int)
    data_FBS = pd.merge( data_FBS, FBS_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')
    
    # Create a combined column for Element + Item
    data_FBS['Element_Item'] = data_FBS['Element'] + "_" + data_FBS['Item']
    
    # Pivot the table
    pivoted_FBS = data_FBS.pivot_table(
        index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
        columns='Element_Item',
        values='Value',
        aggfunc='first'
    ).reset_index()

    return pivoted_FS, pivoted_FBS, pivoted_FBSH

# %%
fs, fbs, fbsh = preprocessing(FBSH_losses, FBS_losses, data_FBS, data_FBSH, data_FS)

# %%
fbs.shape, fs.shape, fbsh.shape
# Out:
# ((13, 16), (46, 14), (14, 16))

# %%
total_losses_per_year_FBSH = FBSH_losses_d.groupby('Year')['Value'].sum().reset_index()
total_losses_per_year_FBSH = total_losses_per_year_FBSH.rename(columns={'Value': 'Total Losses (1000 t)'})

total_losses_per_year_FBS = FBS_losses.groupby('Year')['Value'].sum().reset_index()
total_losses_per_year_FBS = total_losses_per_year_FBS.rename(columns={'Value': 'Total Losses (1000 t)'})

# Merge the total losses back to the original df based on Year
FBSH_losses_sum = pd.merge(FBSH_losses_d, total_losses_per_year_FBSH, on='Year', how='left')
FBS_losses_sum = pd.merge(FBS_losses, total_losses_per_year_FBS, on='Year', how='left')

# %%
FBS_losses_sum.head(2)
# Out:
#   Domain Code                 Domain  Area Code (M49)     Area  Element Code  \
# 0         FBS  Food Balances (2010-)              276  Germany          5123
# 1         FBS  Food Balances (2010-)              276  Germany          5123
#
#   Element Item Code (FBS)                Item  Year Code  Year    Unit  Value  \
# 0  Losses           S2511  Wheat and products       2010  2010  1000 t    638
# 1  Losses           S2511  Wheat and products       2011  2011  1000 t    614
#
#   Flag Flag Description  Note  Total Losses (1000 t)
# 0    I    Imputed value   NaN                   3510
# 1    I    Imputed value   NaN                   3756

# %%
FBSH_losses_sum.head(2)
# Out:
#   Domain Code                                             Domain  \
# 0        FBSH  Food Balances (-2013, old methodology and popu...
# 1        FBSH  Food Balances (-2013, old methodology and popu...
#
#    Area Code (M49)     Area  Element Code Element Item Code (FBS)  \
# 0              276  Germany          5123  Losses           S2617
# 1              276  Germany          5123  Losses           S2615
#
#                   Item  Year Code  Year    Unit  Value Flag Flag Description  \
# 0  Apples and products       2000  2000  1000 t    212    I    Imputed value
# 1              Bananas       2000  2000  1000 t     10    I    Imputed value
#
#    Total Losses (1000 t)
# 0                   4021
# 1                   4021

# %%
# Drop unnecessary columns
FBSH_losses_sum_reduced = FBSH_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')
FBS_losses_sum_reduced = FBS_losses_sum.drop(columns=['Item','Item Code (FBS)', 'Value', 'Flag', 'Flag Description',], errors='ignore')

# Drop duplicate years, keeping the first occurrence
FBSH_losses_sum_reduced = FBSH_losses_sum_reduced.drop_duplicates(subset='Year')
FBS_losses_sum_reduced = FBS_losses_sum_reduced.drop_duplicates(subset='Year')

# %%
FBS_losses_sum_reduced
# Out:
#    Domain Code                 Domain  Area Code (M49)     Area  Element Code  \
# 0          FBS  Food Balances (2010-)              276  Germany          5123
# 1          FBS  Food Balances (2010-)              276  Germany          5123
# 2          FBS  Food Balances (2010-)              276  Germany          5123
# 3          FBS  Food Balances (2010-)              276  Germany          5123
# 4          FBS  Food Balances (2010-)              276  Germany          5123
# 5          FBS  Food Balances (2010-)              276  Germany          5123
# 6          FBS  Food Balances (2010-)              276  Germany          5123
# 7          FBS  Food Balances (2010-)              276  Germany          5123
# 8          FBS  Food Balances (2010-)              276  Germany          5123
# 9          FBS  Food Balances (2010-)              276  Germany          5123
# 10         FBS  Food Balances (2010-)              276  Germany          5123
# 11         FBS  Food Balances (2010-)              276  Germany          5123
# 12         FBS  Food Balances (2010-)              276  Germany          5123
#
#    Element  Year Code  Year    Unit  Note  Total Losses (1000 t)
# 0   Losses       2010  2010  1000 t   NaN                   3510
# 1   Losses       2011  2011  1000 t   NaN                   3756
# 2   Losses       2012  2012  1000 t   NaN                   3748
# 3   Losses       2013  2013  1000 t   NaN                   3797
# 4   Losses       2014  2014  1000 t   NaN                   5075
# 5   Losses       2015  2015  1000 t   NaN                   5120
# 6   Losses       2016  2016  1000 t   NaN                   5498
# 7   Losses       2017  2017  1000 t   NaN                   6159
# 8   Losses       2018  2018  1000 t   NaN                   4421
# 9   Losses       2019  2019  1000 t   NaN                   4790
# 10  Losses       2020  2020  1000 t   NaN                   4862
# 11  Losses       2021  2021  1000 t   NaN                   4882
# 12  Losses       2022  2022  1000 t   NaN                   4591

# %%
FBSH_losses_sum_reduced
# Out:
#     Domain Code                                             Domain  \
# 0          FBSH  Food Balances (-2013, old methodology and popu...
# 37         FBSH  Food Balances (-2013, old methodology and popu...
# 74         FBSH  Food Balances (-2013, old methodology and popu...
# 111        FBSH  Food Balances (-2013, old methodology and popu...
# 148        FBSH  Food Balances (-2013, old methodology and popu...
# 185        FBSH  Food Balances (-2013, old methodology and popu...
# 222        FBSH  Food Balances (-2013, old methodology and popu...
# 259        FBSH  Food Balances (-2013, old methodology and popu...
# 296        FBSH  Food Balances (-2013, old methodology and popu...
# 333        FBSH  Food Balances (-2013, old methodology and popu...
# 370        FBSH  Food Balances (-2013, old methodology and popu...
# 407        FBSH  Food Balances (-2013, old methodology and popu...
# 444        FBSH  Food Balances (-2013, old methodology and popu...
# 481        FBSH  Food Balances (-2013, old methodology and popu...
#
#      Area Code (M49)     Area  Element Code Element  Year Code  Year    Unit  \
# 0                276  Germany          5123  Losses       2000  2000  1000 t
# 37               276  Germany          5123  Losses       2001  2001  1000 t
# 74               276  Germany          5123  Losses       2002  2002  1000 t
# 111              276  Germany          5123  Losses       2003  2003  1000 t
# 148              276  Germany          5123  Losses       2004  2004  1000 t
# 185              276  Germany          5123  Losses       2005  2005  1000 t
# 222              276  Germany          5123  Losses       2006  2006  1000 t
# 259              276  Germany          5123  Losses       2007  2007  1000 t
# 296              276  Germany          5123  Losses       2008  2008  1000 t
# 333              276  Germany          5123  Losses       2009  2009  1000 t
# 370              276  Germany          5123  Losses       2010  2010  1000 t
# 407              276  Germany          5123  Losses       2011  2011  1000 t
# 444              276  Germany          5123  Losses       2012  2012  1000 t
# 481              276  Germany          5123  Losses       2013  2013  1000 t
#
#      Total Losses (1000 t)
# 0                     4021
# 37                    3651
# 74                    3228
# 111                   3061
# 148                   3493
# 185                   3334
# 222                   3377
# 259                   3757
# 296                   3750
# 333                   3862
# 370                   3495
# 407                   3739
# 444                   3734
# 481                   3781

# %%
#FBSH_losses_sum.to_excel("data_FBSH_final.xlsx", index=False)
#FBS_losses_sum.to_excel("data_FBS_final.xlsx", index=False)

# %% [markdown]
# # Transpose data

# %%
# Pivot the table
pivoted_FS = data_FS.pivot_table(
    index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year'],
    columns='Item',
    values='Value',
    aggfunc='first'
).reset_index()

# %%
pivoted_FS.head(2)
# Out:
# Item Domain Code                             Domain  Area Code     Area  \
# 0             FS  Suite of Food Security Indicators         79  Germany
# 1             FS  Suite of Food Security Indicators         79  Germany
#
# Item  Year Code  Year Average dietary energy requirement (kcal/cap/day)  \
# 0          2000  2000                                              2542
# 1          2001  2001                                              2542
#
# Item Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
#
# Item Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)  \
# 0                                                  3423
# 1                                                  3451
#
# Item Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
#
# Item Minimum dietary energy requirement  (kcal/cap/day)  \
# 0                                                  1957
# 1                                                  1957
#
# Item Number of obese adults (18 years and older) (million)  \
# 0                                                  11.8
# 1                                                  12.1
#
# Item Prevalence of obesity in the adult population (18 years and older) (percent)  \
# 0                                                  17.8
# 1                                                  18.2
#
# Item Prevalence of undernourishment (percent) (3-year average)
# 0                                                   NaN
# 1                                                   NaN

# %%
pivoted_FS.shape, pivoted_FS.columns
# Out:
# ((46, 14),
#  Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year',
#         'Average dietary energy requirement (kcal/cap/day)',
#         'Average dietary energy supply adequacy (percent) (3-year average)',
#         'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)',
#         'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)',
#         'Minimum dietary energy requirement  (kcal/cap/day)',
#         'Number of obese adults (18 years and older) (million)',
#         'Prevalence of obesity in the adult population (18 years and older) (percent)',
#         'Prevalence of undernourishment (percent) (3-year average)'],
#        dtype='object', name='Item'))

# %%
# Merge Total Losses (1000 t) to the rest of the data
data_FBSH['Year'] = data_FBSH['Year'].astype(int)
data_FBSH = pd.merge( data_FBSH, FBSH_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')

# Create a combined column for Element + Item
data_FBSH['Element_Item'] = data_FBSH['Element'] + "_" + data_FBSH['Item']

# Pivot the table
pivoted_FBSH = data_FBSH.pivot_table(
    index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
    columns='Element_Item',
    values='Value',
    aggfunc='first'
).reset_index()

# %%
pivoted_FBSH.head(2)
# Out:
# Element_Item Domain Code                                             Domain  \
# 0                   FBSH  Food Balances (-2013, old methodology and popu...
# 1                   FBSH  Food Balances (-2013, old methodology and popu...
#
# Element_Item  Area Code     Area  Year Code  Year  Total Losses (1000 t)  \
# 0                    79  Germany       2000  2000                   4021
# 1                    79  Germany       2001  2001                   3651
#
# Element_Item  Fat supply quantity (g/capita/day)_Animal Products  \
# 0                                                         79.72
# 1                                                         80.39
#
# Element_Item  Fat supply quantity (g/capita/day)_Grand Total  \
# 0                                                     142.80
# 1                                                     137.13
#
# Element_Item  Fat supply quantity (g/capita/day)_Vegetal Products  \
# 0                                                         63.08
# 1                                                         56.74
#
# Element_Item  Food supply (kcal/capita/day)_Animal Products  \
# 0                                                    1012.0
# 1                                                    1029.0
#
# Element_Item  Food supply (kcal/capita/day)_Grand Total  \
# 0                                                3336.0
# 1                                                3363.0
#
# Element_Item  Food supply (kcal/capita/day)_Vegetal Products  \
# 0                                                     2324.0
# 1                                                     2334.0
#
# Element_Item  Protein supply quantity (g/capita/day)_Animal Products  \
# 0                                                         56.48
# 1                                                         58.13
#
# Element_Item  Protein supply quantity (g/capita/day)_Grand Total  \
# 0                                                         94.46
# 1                                                         97.86
#
# Element_Item  Protein supply quantity (g/capita/day)_Vegetal Products
# 0                                                         37.98
# 1                                                         39.73

# %%
pivoted_FBSH.isna().sum()
# Out:
# Element_Item
# Domain Code                                                0
# Domain                                                     0
# Area Code                                                  0
# Area                                                       0
# Year Code                                                  0
# Year                                                       0
# Total Losses (1000 t)                                      0
# Fat supply quantity (g/capita/day)_Animal Products         0
# Fat supply quantity (g/capita/day)_Grand Total             0
# Fat supply quantity (g/capita/day)_Vegetal Products        0
# Food supply (kcal/capita/day)_Animal Products              0
# Food supply (kcal/capita/day)_Grand Total                  0
# Food supply (kcal/capita/day)_Vegetal Products             0
# Protein supply quantity (g/capita/day)_Animal Products     0
# Protein supply quantity (g/capita/day)_Grand Total         0
# Protein supply quantity (g/capita/day)_Vegetal Products    0
# dtype: int64

# %%
pivoted_FS.isna().sum()
# Out:
# Item
# Domain Code                                                                                                            0
# Domain                                                                                                                 0
# Area Code                                                                                                              0
# Area                                                                                                                   0
# Year Code                                                                                                              0
# Year                                                                                                                   0
# Average dietary energy requirement (kcal/cap/day)                                                                     22
# Average dietary energy supply adequacy (percent) (3-year average)                                                     24
# Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)                     22
# Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)    24
# Minimum dietary energy requirement  (kcal/cap/day)                                                                    22
# Number of obese adults (18 years and older) (million)                                                                 23
# Prevalence of obesity in the adult population (18 years and older) (percent)                                          23
# Prevalence of undernourishment (percent) (3-year average)                                                             24
# dtype: int64

# %%
pivoted_FS.loc[pivoted_FS.isnull().any(axis=1)]
# Out:
# Item Domain Code                             Domain  Area Code     Area  \
# 0             FS  Suite of Food Security Indicators         79  Germany
# 1             FS  Suite of Food Security Indicators         79  Germany
# 2             FS  Suite of Food Security Indicators         79  Germany
# 3             FS  Suite of Food Security Indicators         79  Germany
# 4             FS  Suite of Food Security Indicators         79  Germany
# 5             FS  Suite of Food Security Indicators         79  Germany
# 6             FS  Suite of Food Security Indicators         79  Germany
# 7             FS  Suite of Food Security Indicators         79  Germany
# 8             FS  Suite of Food Security Indicators         79  Germany
# 9             FS  Suite of Food Security Indicators         79  Germany
# 10            FS  Suite of Food Security Indicators         79  Germany
# 11            FS  Suite of Food Security Indicators         79  Germany
# 12            FS  Suite of Food Security Indicators         79  Germany
# 13            FS  Suite of Food Security Indicators         79  Germany
# 14            FS  Suite of Food Security Indicators         79  Germany
# 15            FS  Suite of Food Security Indicators         79  Germany
# 16            FS  Suite of Food Security Indicators         79  Germany
# 17            FS  Suite of Food Security Indicators         79  Germany
# 18            FS  Suite of Food Security Indicators         79  Germany
# 19            FS  Suite of Food Security Indicators         79  Germany
# 20            FS  Suite of Food Security Indicators         79  Germany
# 21            FS  Suite of Food Security Indicators         79  Germany
# 22            FS  Suite of Food Security Indicators         79  Germany
# 23            FS  Suite of Food Security Indicators         79  Germany
# 24            FS  Suite of Food Security Indicators         79  Germany
# 25            FS  Suite of Food Security Indicators         79  Germany
# 26            FS  Suite of Food Security Indicators         79  Germany
# 27            FS  Suite of Food Security Indicators         79  Germany
# 28            FS  Suite of Food Security Indicators         79  Germany
# 29            FS  Suite of Food Security Indicators         79  Germany
# 30            FS  Suite of Food Security Indicators         79  Germany
# 31            FS  Suite of Food Security Indicators         79  Germany
# 32            FS  Suite of Food Security Indicators         79  Germany
# 33            FS  Suite of Food Security Indicators         79  Germany
# 34            FS  Suite of Food Security Indicators         79  Germany
# 35            FS  Suite of Food Security Indicators         79  Germany
# 36            FS  Suite of Food Security Indicators         79  Germany
# 37            FS  Suite of Food Security Indicators         79  Germany
# 38            FS  Suite of Food Security Indicators         79  Germany
# 39            FS  Suite of Food Security Indicators         79  Germany
# 40            FS  Suite of Food Security Indicators         79  Germany
# 41            FS  Suite of Food Security Indicators         79  Germany
# 42            FS  Suite of Food Security Indicators         79  Germany
# 43            FS  Suite of Food Security Indicators         79  Germany
# 44            FS  Suite of Food Security Indicators         79  Germany
# 45            FS  Suite of Food Security Indicators         79  Germany
#
# Item  Year Code       Year Average dietary energy requirement (kcal/cap/day)  \
# 0          2000       2000                                              2542
# 1          2001       2001                                              2542
# 2          2002       2002                                              2543
# 3          2003       2003                                              2545
# 4          2004       2004                                              2546
# 5          2005       2005                                              2548
# 6          2006       2006                                              2551
# 7          2007       2007                                              2553
# 8          2008       2008                                              2554
# 9          2009       2009                                              2555
# 10         2010       2010                                              2555
# 11         2011       2011                                              2556
# 12         2012       2012                                              2556
# 13         2013       2013                                              2555
# 14         2014       2014                                              2554
# 15         2015       2015                                              2553
# 16         2016       2016                                              2550
# 17         2017       2017                                              2546
# 18         2018       2018                                              2543
# 19         2019       2019                                              2540
# 20         2020       2020                                              2537
# 21         2021       2021                                              2534
# 22         2022       2022                                              2531
# 23         2023       2023                                              2529
# 24     20002002  2000-2002                                               NaN
# 25     20012003  2001-2003                                               NaN
# 26     20022004  2002-2004                                               NaN
# 27     20032005  2003-2005                                               NaN
# 28     20042006  2004-2006                                               NaN
# 29     20052007  2005-2007                                               NaN
# 30     20062008  2006-2008                                               NaN
# 31     20072009  2007-2009                                               NaN
# 32     20082010  2008-2010                                               NaN
# 33     20092011  2009-2011                                               NaN
# 34     20102012  2010-2012                                               NaN
# 35     20112013  2011-2013                                               NaN
# 36     20122014  2012-2014                                               NaN
# 37     20132015  2013-2015                                               NaN
# 38     20142016  2014-2016                                               NaN
# 39     20152017  2015-2017                                               NaN
# 40     20162018  2016-2018                                               NaN
# 41     20172019  2017-2019                                               NaN
# 42     20182020  2018-2020                                               NaN
# 43     20192021  2019-2021                                               NaN
# 44     20202022  2020-2022                                               NaN
# 45     20212023  2021-2023                                               NaN
#
# Item Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  136
# 25                                                  137
# 26                                                  138
# 27                                                  138
# 28                                                  139
# 29                                                  140
# 30                                                  141
# 31                                                  142
# 32                                                  141
# 33                                                  141
# 34                                                  141
# 35                                                  141
# 36                                                  140
# 37                                                  140
# 38                                                  140
# 39                                                  140
# 40                                                  141
# 41                                                  142
# 42                                                  143
# 43                                                  143
# 44                                                  144
# 45                                                  144
#
# Item Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)  \
# 0                                                  3423
# 1                                                  3451
# 2                                                  3517
# 3                                                  3480
# 4                                                  3503
# 5                                                  3544
# 6                                                  3562
# 7                                                  3627
# 8                                                  3617
# 9                                                  3614
# 10                                                 3596
# 11                                                 3627
# 12                                                 3578
# 13                                                 3566
# 14                                                 3556
# 15                                                 3591
# 16                                                 3576
# 17                                                 3568
# 18                                                 3607
# 19                                                 3635
# 20                                                 3642
# 21                                                 3634
# 22                                                 3657
# 23                                                 3662
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
#
# Item Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                 3464
# 25                                                 3483
# 26                                                 3500
# 27                                                 3509
# 28                                                 3536
# 29                                                 3578
# 30                                                 3602
# 31                                                 3619
# 32                                                 3609
# 33                                                 3612
# 34                                                 3600
# 35                                                 3590
# 36                                                 3567
# 37                                                 3571
# 38                                                 3574
# 39                                                 3578
# 40                                                 3584
# 41                                                 3603
# 42                                                 3628
# 43                                                 3637
# 44                                                 3644
# 45                                                 3651
#
# Item Minimum dietary energy requirement  (kcal/cap/day)  \
# 0                                                  1957
# 1                                                  1957
# 2                                                  1957
# 3                                                  1959
# 4                                                  1959
# 5                                                  1961
# 6                                                  1963
# 7                                                  1964
# 8                                                  1964
# 9                                                  1965
# 10                                                 1965
# 11                                                 1965
# 12                                                 1965
# 13                                                 1965
# 14                                                 1964
# 15                                                 1962
# 16                                                 1960
# 17                                                 1958
# 18                                                 1955
# 19                                                 1953
# 20                                                 1951
# 21                                                 1949
# 22                                                 1947
# 23                                                 1946
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
#
# Item Number of obese adults (18 years and older) (million)  \
# 0                                                  11.8
# 1                                                  12.1
# 2                                                  12.3
# 3                                                  12.6
# 4                                                  12.9
# 5                                                  13.1
# 6                                                  13.3
# 7                                                  13.5
# 8                                                  13.6
# 9                                                  13.7
# 10                                                 13.8
# 11                                                 13.9
# 12                                                 13.9
# 13                                                   14
# 14                                                   14
# 15                                                   14
# 16                                                 14.1
# 17                                                 14.1
# 18                                                 14.1
# 19                                                 14.1
# 20                                                 14.2
# 21                                                 14.2
# 22                                                 14.2
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
#
# Item Prevalence of obesity in the adult population (18 years and older) (percent)  \
# 0                                                  17.8
# 1                                                  18.2
# 2                                                  18.6
# 3                                                    19
# 4                                                  19.3
# 5                                                  19.6
# 6                                                  19.9
# 7                                                  20.1
# 8                                                  20.3
# 9                                                  20.4
# 10                                                 20.4
# 11                                                 20.5
# 12                                                 20.5
# 13                                                 20.4
# 14                                                 20.4
# 15                                                 20.4
# 16                                                 20.4
# 17                                                 20.4
# 18                                                 20.4
# 19                                                 20.4
# 20                                                 20.4
# 21                                                 20.4
# 22                                                 20.4
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# 30                                                  NaN
# 31                                                  NaN
# 32                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                                  NaN
# 36                                                  NaN
# 37                                                  NaN
# 38                                                  NaN
# 39                                                  NaN
# 40                                                  NaN
# 41                                                  NaN
# 42                                                  NaN
# 43                                                  NaN
# 44                                                  NaN
# 45                                                  NaN
#
# Item Prevalence of undernourishment (percent) (3-year average)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                 <2.5
# 25                                                 <2.5
# 26                                                 <2.5
# 27                                                 <2.5
# 28                                                 <2.5
# 29                                                 <2.5
# 30                                                 <2.5
# 31                                                 <2.5
# 32                                                 <2.5
# 33                                                 <2.5
# 34                                                 <2.5
# 35                                                 <2.5
# 36                                                 <2.5
# 37                                                 <2.5
# 38                                                 <2.5
# 39                                                 <2.5
# 40                                                 <2.5
# 41                                                 <2.5
# 42                                                 <2.5
# 43                                                 <2.5
# 44                                                 <2.5
# 45                                                 <2.5

# %%
# Merge Total Losses (1000 t) to the rest of the data
data_FBS['Year'] = data_FBS['Year'].astype(int)
data_FBS = pd.merge( data_FBS, FBS_losses_sum_reduced[['Year', 'Total Losses (1000 t)']], on='Year', how='left')

# Create a combined column for Element + Item
data_FBS['Element_Item'] = data_FBS['Element'] + "_" + data_FBS['Item']

# Pivot the table
pivoted_FBS = data_FBS.pivot_table(
    index=['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year', 'Total Losses (1000 t)'],
    columns='Element_Item',
    values='Value',
    aggfunc='first'
).reset_index()

# %%
pivoted_FBS.head(2)
# Out:
# Element_Item Domain Code                 Domain  Area Code     Area  \
# 0                    FBS  Food Balances (2010-)         79  Germany
# 1                    FBS  Food Balances (2010-)         79  Germany
#
# Element_Item  Year Code  Year  Total Losses (1000 t)  \
# 0                  2010  2010                   3510
# 1                  2011  2011                   3756
#
# Element_Item  Fat supply quantity (g/capita/day)_Animal Products  \
# 0                                                         82.03
# 1                                                         83.13
#
# Element_Item  Fat supply quantity (g/capita/day)_Grand Total  \
# 0                                                     147.99
# 1                                                     149.14
#
# Element_Item  Fat supply quantity (g/capita/day)_Vegetal Products  \
# 0                                                         65.97
# 1                                                         66.01
#
# Element_Item  Food supply (kcal/capita/day)_Animal Products  \
# 0                                                    1114.0
# 1                                                    1124.0
#
# Element_Item  Food supply (kcal/capita/day)_Grand Total  \
# 0                                                3596.0
# 1                                                3627.0
#
# Element_Item  Food supply (kcal/capita/day)_Vegetal Products  \
# 0                                                     2482.0
# 1                                                     2502.0
#
# Element_Item  Protein supply quantity (g/capita/day)_Animal Products  \
# 0                                                         69.69
# 1                                                         69.88
#
# Element_Item  Protein supply quantity (g/capita/day)_Grand Total  \
# 0                                                        109.51
# 1                                                        110.49
#
# Element_Item  Protein supply quantity (g/capita/day)_Vegetal Products
# 0                                                         39.82
# 1                                                         40.61

# %%
pivoted_FBS.shape, pivoted_FBS.columns, pivoted_FBSH.shape, pivoted_FBSH.columns, pivoted_FS.shape, pivoted_FS.columns
# Out:
# ((13, 16),
#  Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year',
#         'Total Losses (1000 t)',
#         'Fat supply quantity (g/capita/day)_Animal Products',
#         'Fat supply quantity (g/capita/day)_Grand Total',
#         'Fat supply quantity (g/capita/day)_Vegetal Products',
#         'Food supply (kcal/capita/day)_Animal Products',
#         'Food supply (kcal/capita/day)_Grand Total',
#         'Food supply (kcal/capita/day)_Vegetal Products',
#         'Protein supply quantity (g/capita/day)_Animal Products',
#         'Protein supply quantity (g/capita/day)_Grand Total',
#         'Protein supply quantity (g/capita/day)_Vegetal Products'],
#        dtype='object', name='Element_Item'),
#  (14, 16),
#  Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year',
#         'Total Losses (1000 t)',
#         'Fat supply quantity (g/capita/day)_Animal Products',
#         'Fat supply quantity (g/capita/day)_Grand Total',
#         'Fat supply quantity (g/capita/day)_Vegetal Products',
#         'Food supply (kcal/capita/day)_Animal Products',
#         'Food supply (kcal/capita/day)_Grand Total',
#         'Food supply (kcal/capita/day)_Vegetal Products',
#         'Protein supply quantity (g/capita/day)_Animal Products',
#         'Protein supply quantity (g/capita/day)_Grand Total',
#         'Protein supply quantity (g/capita/day)_Vegetal Products'],
#        dtype='object', name='Element_Item'),
#  (46, 14),
#  Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Year Code', 'Year',
#         'Average dietary energy requirement (kcal/cap/day)',
#         'Average dietary energy supply adequacy (percent) (3-year average)',
#         'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day)',
#         'Dietary energy supply used in the estimation of the prevalence of undernourishment (kcal/cap/day) (3-year average)',
#         'Minimum dietary energy requirement  (kcal/cap/day)',
#         'Number of obese adults (18 years and older) (million)',
#         'Prevalence of obesity in the adult population (18 years and older) (percent)',
#         'Prevalence of undernourishment (percent) (3-year average)'],
#        dtype='object', name='Item'))

# %%
#Download the edited datasets
#pivoted_FBSH.to_excel("data_FBSH_gr_edited.xlsx", index=False)
#pivoted_FBS.to_excel("data_FBS_gr_edited.xlsx", index=False)
#pivoted_FS.to_excel("data_FS_gr_edited.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 4
#       2 pivoted_FBSH.to_excel("data_FBSH_gr_edited.xlsx", index=False)
#       3 pivoted_FBS.to_excel("data_FBS_gr_edited.xlsx", index=False)
# ----> 4 pivoted_FS.to_excel("data_FS_gr_edited.xlsx", index=False)
#
# NameError: name 'pivoted_FS' is not defined

# %%
pivoted_FBSH
# Out:
# Element_Item Domain Code                                             Domain  \
# 0                   FBSH  Food Balances (-2013, old methodology and popu...
# 1                   FBSH  Food Balances (-2013, old methodology and popu...
# 2                   FBSH  Food Balances (-2013, old methodology and popu...
# 3                   FBSH  Food Balances (-2013, old methodology and popu...
# 4                   FBSH  Food Balances (-2013, old methodology and popu...
# 5                   FBSH  Food Balances (-2013, old methodology and popu...
# 6                   FBSH  Food Balances (-2013, old methodology and popu...
# 7                   FBSH  Food Balances (-2013, old methodology and popu...
# 8                   FBSH  Food Balances (-2013, old methodology and popu...
# 9                   FBSH  Food Balances (-2013, old methodology and popu...
# 10                  FBSH  Food Balances (-2013, old methodology and popu...
# 11                  FBSH  Food Balances (-2013, old methodology and popu...
# 12                  FBSH  Food Balances (-2013, old methodology and popu...
# 13                  FBSH  Food Balances (-2013, old methodology and popu...
#
# Element_Item  Area Code     Area  Year Code  Year  Total Losses (1000 t)  \
# 0                    79  Germany       2000  2000                   4021
# 1                    79  Germany       2001  2001                   3651
# 2                    79  Germany       2002  2002                   3228
# 3                    79  Germany       2003  2003                   3061
# 4                    79  Germany       2004  2004                   3493
# 5                    79  Germany       2005  2005                   3334
# 6                    79  Germany       2006  2006                   3377
# 7                    79  Germany       2007  2007                   3757
# 8                    79  Germany       2008  2008                   3750
# 9                    79  Germany       2009  2009                   3862
# 10                   79  Germany       2010  2010                   3495
# 11                   79  Germany       2011  2011                   3739
# 12                   79  Germany       2012  2012                   3734
# 13                   79  Germany       2013  2013                   3781
#
# Element_Item  Fat supply quantity (g/capita/day)_Animal Products  \
# 0                                                         79.72
# 1                                                         80.39
# 2                                                         81.93
# 3                                                         82.33
# 4                                                         79.77
# 5                                                         80.55
# 6                                                         79.37
# 7                                                         82.33
# 8                                                         80.24
# 9                                                         80.52
# 10                                                        81.99
# 11                                                        83.10
# 12                                                        80.03
# 13                                                        78.00
#
# Element_Item  Fat supply quantity (g/capita/day)_Grand Total  \
# 0                                                     142.80
# 1                                                     137.13
# 2                                                     139.04
# 3                                                     139.19
# 4                                                     138.58
# 5                                                     138.96
# 6                                                     140.72
# 7                                                     146.00
# 8                                                     144.11
# 9                                                     142.81
# 10                                                    144.10
# 11                                                    145.65
# 12                                                    144.31
# 13                                                    141.87
#
# Element_Item  Fat supply quantity (g/capita/day)_Vegetal Products  \
# 0                                                         63.08
# 1                                                         56.74
# 2                                                         57.11
# 3                                                         56.85
# 4                                                         58.81
# 5                                                         58.41
# 6                                                         61.34
# 7                                                         63.67
# 8                                                         63.87
# 9                                                         62.29
# 10                                                        62.10
# 11                                                        62.54
# 12                                                        64.29
# 13                                                        63.87
#
# Element_Item  Food supply (kcal/capita/day)_Animal Products  \
# 0                                                    1012.0
# 1                                                    1029.0
# 2                                                    1048.0
# 3                                                    1063.0
# 4                                                    1037.0
# 5                                                    1047.0
# 6                                                    1045.0
# 7                                                    1084.0
# 8                                                    1061.0
# 9                                                    1074.0
# 10                                                   1079.0
# 11                                                   1090.0
# 12                                                   1061.0
# 13                                                   1044.0
#
# Element_Item  Food supply (kcal/capita/day)_Grand Total  \
# 0                                                3336.0
# 1                                                3363.0
# 2                                                3427.0
# 3                                                3390.0
# 4                                                3411.0
# 5                                                3450.0
# 6                                                3466.0
# 7                                                3527.0
# 8                                                3517.0
# 9                                                3515.0
# 10                                               3504.0
# 11                                               3538.0
# 12                                               3501.0
# 13                                               3499.0
#
# Element_Item  Food supply (kcal/capita/day)_Vegetal Products  \
# 0                                                     2324.0
# 1                                                     2334.0
# 2                                                     2379.0
# 3                                                     2328.0
# 4                                                     2375.0
# 5                                                     2403.0
# 6                                                     2421.0
# 7                                                     2443.0
# 8                                                     2456.0
# 9                                                     2441.0
# 10                                                    2425.0
# 11                                                    2447.0
# 12                                                    2439.0
# 13                                                    2454.0
#
# Element_Item  Protein supply quantity (g/capita/day)_Animal Products  \
# 0                                                         56.48
# 1                                                         58.13
# 2                                                         58.10
# 3                                                         59.55
# 4                                                         58.20
# 5                                                         58.35
# 6                                                         59.70
# 7                                                         62.00
# 8                                                         61.38
# 9                                                         62.34
# 10                                                        61.84
# 11                                                        62.23
# 12                                                        61.80
# 13                                                        61.48
#
# Element_Item  Protein supply quantity (g/capita/day)_Grand Total  \
# 0                                                         94.46
# 1                                                         97.86
# 2                                                         99.00
# 3                                                         97.95
# 4                                                         96.73
# 5                                                         96.96
# 6                                                         99.18
# 7                                                        102.49
# 8                                                        101.28
# 9                                                        102.56
# 10                                                       101.89
# 11                                                       103.19
# 12                                                       101.81
# 13                                                       101.59
#
# Element_Item  Protein supply quantity (g/capita/day)_Vegetal Products
# 0                                                         37.98
# 1                                                         39.73
# 2                                                         40.89
# 3                                                         38.40
# 4                                                         38.53
# 5                                                         38.61
# 6                                                         39.48
# 7                                                         40.50
# 8                                                         39.89
# 9                                                         40.22
# 10                                                        40.05
# 11                                                        40.95
# 12                                                        40.01
# 13                                                        40.11

# %% [markdown]
# # Moving average processing

# %%
final_data_gr = pd.read_csv("")

# %%
data_FS.head(2)
# Out:
#   Domain Code                             Domain  Area Code     Area  \
# 0          FS  Suite of Food Security Indicators         79  Germany
# 1          FS  Suite of Food Security Indicators         79  Germany
#
#    Element Code Element  Item Code  \
# 0          6121   Value      21010
# 1          6121   Value      21010
#
#                                                 Item  Year Code       Year  \
# 0  Average dietary energy supply adequacy (percen...   20002002  2000-2002
# 1  Average dietary energy supply adequacy (percen...   20012003  2001-2003
#
#   Unit Value
# 0    %   136
# 1    %   137

# %% [markdown]
# # Data exploration
